# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from lightgbm.sklearn import LGBMClassifier
from sklearn.metrics import roc_auc_score, f1_score
from scipy.stats import entropy
from gensim.models import Word2Vec
import time
import gc
import os

import tqdm                                                                                                   
import concurrent.futures
import multiprocessing

pd.set_option('display.max_columns', None)
num_processes = multiprocessing.cpu_count()
print("total cpu count", +num_processes) 

os.environ['NUMEXPR_MAX_THREADS'] = '8'

from core.utils import timeit, reduce_mem
# Out:
# total cpu count 8

# %%
path = "/media/ryan/F/deep-learning-data/turing/vedio-predict/"

path_sub = path + 'sub/'
path_npy = path + 'npy/'
path_data = path + 'raw/'
path_model = path + 'model/'
path_result = path + 'result/'
path_pickle = path + 'pickle/'
path_profile = path + 'profile/'

debug_small = False

if debug_small:
    train_df = pd.read_pickle(path_pickle + 'train_small.pickle')
    test_df = pd.read_pickle(path_pickle + 'test_small.pickle')
    sub = pd.read_csv(path_data + 'sample.csv')

    # app = pd.read_pickle(path_pickle + 'app_small.pickle')
    # user = pd.read_pickle(path_pickle + 'user_small.pickle')
else:
    train_df = pd.read_pickle(path_pickle + 'train.pickle')
    test_df = pd.read_pickle(path_pickle + 'test.pickle')
    sub = pd.read_csv(path_data + 'sample.csv')

    # app = pd.read_pickle(path_pickle + 'app.pickle')
    # user = pd.read_pickle(path_pickle + 'user.pickle')

# %%
train_df = train_df[train_df.deviceid.str[-1] == '1']
test_df = test_df[test_df.deviceid.str[-1] == '1']

# %%
test_df
# Out:
#                    id                          deviceid               newsid  \
# 101          test_102  fc2537a764aeebad1d9738bd835830c1  1026782592186002955
# 102          test_103  fc2537a764aeebad1d9738bd835830c1  1114886426938376594
# 103          test_104  fc2537a764aeebad1d9738bd835830c1  1121986237192882413
# 104          test_105  fc2537a764aeebad1d9738bd835830c1  1192685813446768337
# 105          test_106  fc2537a764aeebad1d9738bd835830c1  1394102932340986804
# ...               ...                               ...                  ...
# 3653372  test_3653373  6676636e0343e2a2b02b9aec8be3ae31  3200871213877970645
# 3653382  test_3653383  f0948752a64440a9cf8a11e330656f81  1497816818221073735
# 3653383  test_3653384  f0948752a64440a9cf8a11e330656f81  3860129264619378056
# 3653384  test_3653385  f0948752a64440a9cf8a11e330656f81  4052357272046746699
# 3653385  test_3653386  f0948752a64440a9cf8a11e330656f81  8578357337510077264
#
#                                      guid  pos app_version device_vendor  \
# 101      7a7e251a3a8a3e51f304558189d920f8    3       2.1.5          OPPO
# 102      7a7e251a3a8a3e51f304558189d920f8    4       2.1.5          OPPO
# 103      7a7e251a3a8a3e51f304558189d920f8    2       2.1.5          OPPO
# 104      7a7e251a3a8a3e51f304558189d920f8    4       2.1.5          OPPO
# 105      7a7e251a3a8a3e51f304558189d920f8    1       2.1.5          OPPO
# ...                                   ...  ...         ...           ...
# 3653372  7f02e3b78cfc49257dc5f326619a7086    1       2.1.5         HONOR
# 3653382  1f5918b9c85e3bf02008720c565b277d    1       2.0.8          vivo
# 3653383  1f5918b9c85e3bf02008720c565b277d    2       2.0.8          vivo
# 3653384  1f5918b9c85e3bf02008720c565b277d    0       2.0.8          vivo
# 3653385  1f5918b9c85e3bf02008720c565b277d    1       2.0.8          vivo
#
#         netmodel osversion            lng            lat device_version  \
# 101            o     8.1.0   1.060673e+02   2.796026e+01         PBCM10
# 102            o     8.1.0  4.940656e-324  4.940656e-324         PBCM10
# 103            o     8.1.0   1.060673e+02   2.796026e+01         PBCM10
# 104            o     8.1.0   1.060673e+02   2.796026e+01         PBCM10
# 105            o     8.1.0   1.060673e+02   2.796026e+01         PBCM10
# ...          ...       ...            ...            ...            ...
# 3653372        w         9   1.172218e+02   3.070950e+01       JSN-AL00
# 3653382        o     8.1.0  4.940656e-324  4.940656e-324        V1813BT
# 3653383        o     8.1.0  4.940656e-324  4.940656e-324        V1813BT
# 3653384        w     8.1.0  4.940656e-324  4.940656e-324        V1813BT
# 3653385        w     8.1.0  4.940656e-324  4.940656e-324        V1813BT
#
#                     ts
# 101      1573450717181
# 102      1573445772769
# 103      1573450525650
# 104      1573449290652
# 105      1573449626574
# ...                ...
# 3653372  1573439588837
# 3653382  1573480884142
# 3653383  1573480717292
# 3653384  1573481111925
# 3653385  1573481111947
#
# [237323 rows x 13 columns]

# %%
sub = sub[sub.id.isin(test_df.id) ]
sub
# Out:
#                    id  target
# 101          test_102       1
# 102          test_103       0
# 103          test_104       1
# 104          test_105       0
# 105          test_106       1
# ...               ...     ...
# 3653372  test_3653373       0
# 3653382  test_3653383       0
# 3653383  test_3653384       1
# 3653384  test_3653385       0
# 3653385  test_3653386       1
#
# [237323 rows x 2 columns]

# %%
print('=============================================== read train ===============================================')
t = time.time()
# train_df = pd.read_csv('dataset/train.csv')
train_df['date'] = pd.to_datetime(
    train_df['ts'].apply(lambda x: time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(x / 1000)))
)
train_df['day'] = train_df['date'].dt.day

# 训练集中，day=7的个数为11个，day=8的为3,674,871。 day9，10也是解决40w
# day=7占比不到1/百万，属于异常情况，去掉合理？ 线上的表现又会如何，为啥不是直接删除，这样有点过了
# 这里为啥只是改了day，不去直接改ts和timestamp呢？
train_df.loc[train_df['day'] == 7, 'day'] = 8
train_df['hour'] = train_df['date'].dt.hour
train_df['minute'] = train_df['date'].dt.minute
train_num = train_df.shape[0]
labels = train_df['target'].values
print('runtime:', time.time() - t)
# Out:
# =============================================== read train ===============================================
# runtime: 22.714237213134766

# %%
print('=============================================== click data ===============================================')
click_df = train_df[train_df['target'] == 1].sort_values('timestamp').reset_index(drop=True)
click_df['exposure_click_gap'] = click_df['timestamp'] - click_df['ts']
click_df = click_df[click_df['exposure_click_gap'] >= 0].reset_index(drop=True)
click_df['date'] = pd.to_datetime(
    click_df['timestamp'].apply(lambda x: time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(x / 1000)))
)
click_df['day'] = click_df['date'].dt.day
# 同上对day==7的修改
click_df.loc[click_df['day'] == 7, 'day'] = 8

del train_df['target'], train_df['timestamp']

# 这里为啥要把click_df的这些字段删除呢？
for f in ['date', 'exposure_click_gap', 'timestamp', 'ts', 'target', 'hour', 'minute']:
    del click_df[f]
print('runtime:', time.time() - t)
# Out:
# =============================================== click data ===============================================
# runtime: 7.2453343868255615

# %%
print('=============================================== read test ===============================================')
test_df['date'] = pd.to_datetime(
    test_df['ts'].apply(lambda x: time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(x / 1000)))
)
test_df['day'] = test_df['date'].dt.day

# 测试集中，day=10的个数为32个，day=11的为3,653,560占比 1/十万，属于异常情况，去掉合理
test_df.loc[test_df['day'] == 10, 'day'] = 11
test_df['hour'] = test_df['date'].dt.hour
test_df['minute'] = test_df['date'].dt.minute
df = pd.concat([train_df, test_df], axis=0, ignore_index=False)
del train_df, test_df, df['date']
gc.collect()
print('runtime:', time.time() - t)
# Out:
# =============================================== read test ===============================================
# runtime: 11.870017051696777

# %%
print('============================================= category encoding =============================================')
df['lng_lat'] = df['lng'].astype('str') + '_' + df['lat'].astype('str')
del df['guid']
click_df['lng_lat'] = click_df['lng'].astype('str') + '_' + click_df['lat'].astype('str')
sort_df = df.sort_values('ts').reset_index(drop=True)
cate_cols = [
    'deviceid', 'newsid', 'pos', 'app_version', 'device_vendor',
    'netmodel', 'osversion', 'device_version', 'lng', 'lat', 'lng_lat'
]
for f in cate_cols:
    print(f)
    map_dict = dict(zip(df[f].unique(), range(df[f].nunique())))
    df[f] = df[f].map(map_dict).fillna(-1).astype('int32')
    click_df[f] = click_df[f].map(map_dict).fillna(-1).astype('int32')
    sort_df[f] = sort_df[f].map(map_dict).fillna(-1).astype('int32')
    df[f + '_count'] = df[f].map(df[f].value_counts())
df = reduce_mem(df)
click_df = reduce_mem(click_df)
sort_df = reduce_mem(sort_df)
print('runtime:', time.time() - t)
# Out:
# ============================================= category encoding =============================================
# deviceid
# newsid
# pos
# app_version
# device_vendor
# netmodel
# osversion
# device_version
# lng
# lat
# lng_lat
# 166.76 Mb, 81.53 Mb (51.11 %)
# 4.87 Mb, 2.29 Mb (52.94 %)
# 77.82 Mb, 35.20 Mb (54.76 %)
# runtime: 23.73936653137207

# %%
print('============================================= feat engineer =============================================')

print('*************************** history stats ***************************')
for f in [
    ['deviceid'],
    ['pos', 'deviceid'],
    # ...
]:
    print('------------------ {} ------------------'.format('_'.join(f)))

    # 对前一天的点击次数进行统计
    tmp = click_df[f + ['day', 'id']].groupby(f + ['day'], as_index=False)['id'].agg(
        {'_'.join(f) + '_prev_day_click_count': 'count'})
    tmp['day'] += 1
    df = df.merge(tmp, on=f + ['day'], how='left')
    df['_'.join(f) + '_prev_day_click_count'] = df['_'.join(f) + '_prev_day_click_count'].fillna(0)
    df.loc[df['day'] == 8, '_'.join(f) + '_prev_day_click_count'] = None

    # 对前一天的曝光量进行统计
    tmp = df[f + ['day', 'id']].groupby(f + ['day'], as_index=False)['id'].agg(
        {'_'.join(f) + '_prev_day_count': 'count'})
    tmp['day'] += 1
    df = df.merge(tmp, on=f + ['day'], how='left')
    df['_'.join(f) + '_prev_day_count'] = df['_'.join(f) + '_prev_day_count'].fillna(0)
    df.loc[df['day'] == 8, '_'.join(f) + '_prev_day_count'] = None

    # 计算前一天的点击率
    df['_'.join(f) + '_prev_day_ctr'] = df['_'.join(f) + '_prev_day_click_count'] / (
            df['_'.join(f) + '_prev_day_count'] + df['_'.join(f) + '_prev_day_count'].mean())

    del tmp
    print('runtime:', time.time() - t)
del click_df
df = reduce_mem(df)
# Out:
# ============================================= feat engineer =============================================
# *************************** history stats ***************************
# ------------------ deviceid ------------------
# runtime: 24.4334557056427
# ------------------ pos_deviceid ------------------
# runtime: 25.21677041053772
# 126.00 Mb, 92.64 Mb (26.47 %)

# %%
print('*************************** exposure_ts_gap ***************************')
for f in [
    ['deviceid'], ['newsid'], ['lng_lat'],
    ['pos', 'deviceid'], ['pos', 'newsid'], ['pos', 'lng_lat'],
    ['pos', 'deviceid', 'lng_lat'],
    ['netmodel', 'deviceid'],
    ['pos', 'netmodel', 'deviceid'],
    ['netmodel', 'lng_lat'], ['deviceid', 'lng_lat'],
    ['netmodel', 'deviceid', 'lng_lat'], ['pos', 'netmodel', 'lng_lat'],
    ['pos', 'netmodel', 'deviceid', 'lng_lat']
]:
    print('------------------ {} ------------------'.format('_'.join(f)))

    tmp = sort_df[f + ['ts']].groupby(f)
    # 前x次、后x次曝光到当前的时间差
    for gap in [1, 2, 3, 5, 10]:
        sort_df['{}_prev{}_exposure_ts_gap'.format('_'.join(f), gap)] = tmp['ts'].shift(0) - tmp['ts'].shift(gap)
        sort_df['{}_next{}_exposure_ts_gap'.format('_'.join(f), gap)] = tmp['ts'].shift(-gap) - tmp['ts'].shift(0)
        tmp2 = sort_df[
            f + ['ts', '{}_prev{}_exposure_ts_gap'.format('_'.join(f), gap),
                 '{}_next{}_exposure_ts_gap'.format('_'.join(f), gap)]
            ].drop_duplicates(f + ['ts']).reset_index(drop=True)
        df = df.merge(tmp2, on=f + ['ts'], how='left')
        del sort_df['{}_prev{}_exposure_ts_gap'.format('_'.join(f), gap)]
        del sort_df['{}_next{}_exposure_ts_gap'.format('_'.join(f), gap)]
        del tmp2

    del tmp
    df = reduce_mem(df)
    print('runtime:', time.time() - t)
del df['ts']
gc.collect()
# Out:
# *************************** exposure_ts_gap ***************************
# ------------------ deviceid ------------------
# 166.76 Mb, 129.70 Mb (22.22 %)
# runtime: 34.02491521835327
# ------------------ newsid ------------------
# 203.82 Mb, 166.76 Mb (18.18 %)
# runtime: 39.63182067871094
# ------------------ lng_lat ------------------
# 240.87 Mb, 203.82 Mb (15.38 %)
# runtime: 44.98241329193115
# ------------------ pos_deviceid ------------------
# 277.93 Mb, 240.87 Mb (13.33 %)
# runtime: 50.920658349990845
# ------------------ pos_newsid ------------------
# 314.99 Mb, 277.93 Mb (11.76 %)
# runtime: 57.91858744621277
# ------------------ pos_lng_lat ------------------
# 352.05 Mb, 314.99 Mb (10.53 %)
# runtime: 64.49775505065918
# ------------------ pos_deviceid_lng_lat ------------------
# 389.10 Mb, 352.05 Mb (9.52 %)
# runtime: 71.71031022071838
# ------------------ netmodel_deviceid ------------------
# 426.16 Mb, 389.10 Mb (8.70 %)
# runtime: 78.98814296722412
# ------------------ pos_netmodel_deviceid ------------------
# 463.22 Mb, 426.16 Mb (8.00 %)
# runtime: 86.86800599098206
# ------------------ netmodel_lng_lat ------------------
# 500.28 Mb, 463.22 Mb (7.41 %)
# runtime: 94.89772295951843
# ------------------ deviceid_lng_lat ------------------
# 537.33 Mb, 500.28 Mb (6.90 %)
# runtime: 103.21534514427185
# ------------------ netmodel_deviceid_lng_lat ------------------
# 574.39 Mb, 537.33 Mb (6.45 %)
# runtime: 112.12956237792969
# ------------------ pos_netmodel_lng_lat ------------------
# 611.45 Mb, 574.39 Mb (6.06 %)
# runtime: 121.53678750991821
# ------------------ pos_netmodel_deviceid_lng_lat ------------------
# 648.51 Mb, 611.45 Mb (5.71 %)
# runtime: 131.37528610229492
# 0

# %%
# print('*************************** cross feat (second order) ***************************')
# # 二阶交叉特征，可以继续做更高阶的交叉。
# def build_cross_feat(df, f, col):
#     print('------------------ {} {} ------------------'.format(f, col))
#     df = df.merge(df[[f, col]].groupby(f, as_index=False)[col].agg({
#         'cross_{}_{}_nunique'.format(f, col): 'nunique',
#         'cross_{}_{}_ent'.format(f, col): lambda x: entropy(x.value_counts() / x.shape[0])  # 熵
#     }), on=f, how='left')
#     if 'cross_{}_{}_count'.format(f, col) not in df.columns.values and 'cross_{}_{}_count'.format(col,
#                                                                                                   f) not in df.columns.values:
#         df = df.merge(df[[f, col, 'id']].groupby([f, col], as_index=False)['id'].agg({
#             'cross_{}_{}_count'.format(f, col): 'count'  # 共现次数
#         }), on=[f, col], how='left')
#     if 'cross_{}_{}_count_ratio'.format(col, f) not in df.columns.values:
#         df['cross_{}_{}_count_ratio'.format(col, f)] = df['cross_{}_{}_count'.format(f, col)] / df[
#             f + '_count']  # 比例偏好
#     if 'cross_{}_{}_count_ratio'.format(f, col) not in df.columns.values:
#         df['cross_{}_{}_count_ratio'.format(f, col)] = df['cross_{}_{}_count'.format(f, col)] / df[
#             col + '_count']  # 比例偏好
#     df['cross_{}_{}_nunique_ratio_{}_count'.format(f, col, f)] = df['cross_{}_{}_nunique'.format(f, col)] / df[
#         f + '_count']
#     print('runtime:', time.time() - t)
#     df = reduce_mem(df)
#     return df
        
# cross_cols = ['deviceid', 'newsid', 'pos', 'netmodel', 'lng_lat']
# f_col_tuple_list = []
# for f in cross_cols:
#     for col in cross_cols:
#         if col == f:
#             continue
#         f_col_tuple_list.append((f, col))
        
# print(f_col_tuple_list)
# # with concurrent.futures.ProcessPoolExecutor(num_processes) as pool:
# #     df = list(tqdm.tqdm(pool.map(build_cross_feat, cross_cols, chunksize=10, total=df.shape[0])))
# for tuple_o in tqdm.tqdm(f_col_tuple_list):
#     print(tuple_o)
#     df = build_cross_feat(df, tuple_o[0], tuple_o[1])

# del df['id']
# gc.collect()

# %%
df.columns.values
# Out:
# array(['id', 'deviceid', 'newsid', 'pos', 'app_version', 'device_vendor',
#        'netmodel', 'osversion', 'lng', 'lat', 'device_version', 'day',
#        'hour', 'minute', 'lng_lat', 'deviceid_count', 'newsid_count',
#        'pos_count', 'app_version_count', 'device_vendor_count',
#        'netmodel_count', 'osversion_count', 'device_version_count',
#        'lng_count', 'lat_count', 'lng_lat_count',
#        'deviceid_prev_day_click_count', 'deviceid_prev_day_count',
#        'deviceid_prev_day_ctr', 'pos_deviceid_prev_day_click_count',
#        'pos_deviceid_prev_day_count', 'pos_deviceid_prev_day_ctr',
#        'deviceid_prev1_exposure_ts_gap', 'deviceid_next1_exposure_ts_gap',
#        'deviceid_prev2_exposure_ts_gap', 'deviceid_next2_exposure_ts_gap',
#        'deviceid_prev3_exposure_ts_gap', 'deviceid_next3_exposure_ts_gap',
#        'deviceid_prev5_exposure_ts_gap', 'deviceid_next5_exposure_ts_gap',
#        'deviceid_prev10_exposure_ts_gap',
#        'deviceid_next10_exposure_ts_gap', 'newsid_prev1_exposure_ts_gap',
#        'newsid_next1_exposure_ts_gap', 'newsid_prev2_exposure_ts_gap',
#        'newsid_next2_exposure_ts_gap', 'newsid_prev3_exposure_ts_gap',
#        'newsid_next3_exposure_ts_gap', 'newsid_prev5_exposure_ts_gap',
#        'newsid_next5_exposure_ts_gap', 'newsid_prev10_exposure_ts_gap',
#        'newsid_next10_exposure_ts_gap', 'lng_lat_prev1_exposure_ts_gap',
#        'lng_lat_next1_exposure_ts_gap', 'lng_lat_prev2_exposure_ts_gap',
#        'lng_lat_next2_exposure_ts_gap', 'lng_lat_prev3_exposure_ts_gap',
#        'lng_lat_next3_exposure_ts_gap', 'lng_lat_prev5_exposure_ts_gap',
#        'lng_lat_next5_exposure_ts_gap', 'lng_lat_prev10_exposure_ts_gap',
#        'lng_lat_next10_exposure_ts_gap',
#        'pos_deviceid_prev1_exposure_ts_gap',
#        'pos_deviceid_next1_exposure_ts_gap',
#        'pos_deviceid_prev2_exposure_ts_gap',
#        'pos_deviceid_next2_exposure_ts_gap',
#        'pos_deviceid_prev3_exposure_ts_gap',
#        'pos_deviceid_next3_exposure_ts_gap',
#        'pos_deviceid_prev5_exposure_ts_gap',
#        'pos_deviceid_next5_exposure_ts_gap',
#        'pos_deviceid_prev10_exposure_ts_gap',
#        'pos_deviceid_next10_exposure_ts_gap',
#        'pos_newsid_prev1_exposure_ts_gap',
#        'pos_newsid_next1_exposure_ts_gap',
#        'pos_newsid_prev2_exposure_ts_gap',
#        'pos_newsid_next2_exposure_ts_gap',
#        'pos_newsid_prev3_exposure_ts_gap',
#        'pos_newsid_next3_exposure_ts_gap',
#        'pos_newsid_prev5_exposure_ts_gap',
#        'pos_newsid_next5_exposure_ts_gap',
#        'pos_newsid_prev10_exposure_ts_gap',
#        'pos_newsid_next10_exposure_ts_gap',
#        'pos_lng_lat_prev1_exposure_ts_gap',
#        'pos_lng_lat_next1_exposure_ts_gap',
#        'pos_lng_lat_prev2_exposure_ts_gap',
#        'pos_lng_lat_next2_exposure_ts_gap',
#        'pos_lng_lat_prev3_exposure_ts_gap',
#        'pos_lng_lat_next3_exposure_ts_gap',
#        'pos_lng_lat_prev5_exposure_ts_gap',
#        'pos_lng_lat_next5_exposure_ts_gap',
#        'pos_lng_lat_prev10_exposure_ts_gap',
#        'pos_lng_lat_next10_exposure_ts_gap',
#        'pos_deviceid_lng_lat_prev1_exposure_ts_gap',
#        'pos_deviceid_lng_lat_next1_exposure_ts_gap',
#        'pos_deviceid_lng_lat_prev2_exposure_ts_gap',
#        'pos_deviceid_lng_lat_next2_exposure_ts_gap',
#        'pos_deviceid_lng_lat_prev3_exposure_ts_gap',
#        'pos_deviceid_lng_lat_next3_exposure_ts_gap',
#        'pos_deviceid_lng_lat_prev5_exposure_ts_gap',
#        'pos_deviceid_lng_lat_next5_exposure_ts_gap',
#        'pos_deviceid_lng_lat_prev10_exposure_ts_gap',
#        'pos_deviceid_lng_lat_next10_exposure_ts_gap',
#        'netmodel_deviceid_prev1_exposure_ts_gap',
#        'netmodel_deviceid_next1_exposure_ts_gap',
#        'netmodel_deviceid_prev2_exposure_ts_gap',
#        'netmodel_deviceid_next2_exposure_ts_gap',
#        'netmodel_deviceid_prev3_exposure_ts_gap',
#        'netmodel_deviceid_next3_exposure_ts_gap',
#        'netmodel_deviceid_prev5_exposure_ts_gap',
#        'netmodel_deviceid_next5_exposure_ts_gap',
#        'netmodel_deviceid_prev10_exposure_ts_gap',
#        'netmodel_deviceid_next10_exposure_ts_gap',
#        'pos_netmodel_deviceid_prev1_exposure_ts_gap',
#        'pos_netmodel_deviceid_next1_exposure_ts_gap',
#        'pos_netmodel_deviceid_prev2_exposure_ts_gap',
#        'pos_netmodel_deviceid_next2_exposure_ts_gap',
#        'pos_netmodel_deviceid_prev3_exposure_ts_gap',
#        'pos_netmodel_deviceid_next3_exposure_ts_gap',
#        'pos_netmodel_deviceid_prev5_exposure_ts_gap',
#        'pos_netmodel_deviceid_next5_exposure_ts_gap',
#        'pos_netmodel_deviceid_prev10_exposure_ts_gap',
#        'pos_netmodel_deviceid_next10_exposure_ts_gap',
#        'netmodel_lng_lat_prev1_exposure_ts_gap',
#        'netmodel_lng_lat_next1_exposure_ts_gap',
#        'netmodel_lng_lat_prev2_exposure_ts_gap',
#        'netmodel_lng_lat_next2_exposure_ts_gap',
#        'netmodel_lng_lat_prev3_exposure_ts_gap',
#        'netmodel_lng_lat_next3_exposure_ts_gap',
#        'netmodel_lng_lat_prev5_exposure_ts_gap',
#        'netmodel_lng_lat_next5_exposure_ts_gap',
#        'netmodel_lng_lat_prev10_exposure_ts_gap',
#        'netmodel_lng_lat_next10_exposure_ts_gap',
#        'deviceid_lng_lat_prev1_exposure_ts_gap',
#        'deviceid_lng_lat_next1_exposure_ts_gap',
#        'deviceid_lng_lat_prev2_exposure_ts_gap',
#        'deviceid_lng_lat_next2_exposure_ts_gap',
#        'deviceid_lng_lat_prev3_exposure_ts_gap',
#        'deviceid_lng_lat_next3_exposure_ts_gap',
#        'deviceid_lng_lat_prev5_exposure_ts_gap',
#        'deviceid_lng_lat_next5_exposure_ts_gap',
#        'deviceid_lng_lat_prev10_exposure_ts_gap',
#        'deviceid_lng_lat_next10_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_prev1_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_next1_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_prev2_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_next2_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_prev3_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_next3_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_prev5_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_next5_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_prev10_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_next10_exposure_ts_gap',
#        'pos_netmodel_lng_lat_prev1_exposure_ts_gap',
#        'pos_netmodel_lng_lat_next1_exposure_ts_gap',
#        'pos_netmodel_lng_lat_prev2_exposure_ts_gap',
#        'pos_netmodel_lng_lat_next2_exposure_ts_gap',
#        'pos_netmodel_lng_lat_prev3_exposure_ts_gap',
#        'pos_netmodel_lng_lat_next3_exposure_ts_gap',
#        'pos_netmodel_lng_lat_prev5_exposure_ts_gap',
#        'pos_netmodel_lng_lat_next5_exposure_ts_gap',
#        'pos_netmodel_lng_lat_prev10_exposure_ts_gap',
#        'pos_netmodel_lng_lat_next10_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_prev1_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_next1_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_prev2_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_next2_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_prev3_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_next3_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_prev5_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_next5_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_prev10_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_next10_exposure_ts_gap'],
#       dtype=object)

# %%
print('*************************** cross feat (second order) ***************************')
# 二阶交叉特征，可以继续做更高阶的交叉。
cross_cols = ['deviceid', 'newsid', 'pos', 'netmodel', 'lng_lat']
for f in cross_cols:
    for col in cross_cols:
        if col == f:
            continue
        print('------------------ {} {} ------------------'.format(f, col))
        if  'cross_{}_{}_nunique'.format(f, col) not in df.columns.values:
            df = df.merge(df[[f, col]].groupby(f, as_index=False)[col].agg({
                'cross_{}_{}_nunique'.format(f, col): 'nunique',
                'cross_{}_{}_ent'.format(f, col): lambda x: entropy(x.value_counts() / x.shape[0])  # 熵
            }), on=f, how='left')
        if 'cross_{}_{}_count'.format(f, col) not in df.columns.values and 'cross_{}_{}_count'.format(col,
                                                                                                      f) not in df.columns.values:
            df = df.merge(df[[f, col, 'id']].groupby([f, col], as_index=False)['id'].agg({
                'cross_{}_{}_count'.format(f, col): 'count'  # 共现次数
            }), on=[f, col], how='left')
        if 'cross_{}_{}_count_ratio'.format(col, f) not in df.columns.values:
            df['cross_{}_{}_count_ratio'.format(col, f)] = df['cross_{}_{}_count'.format(f, col)] / df[
                f + '_count']  # 比例偏好
        if 'cross_{}_{}_count_ratio'.format(f, col) not in df.columns.values:
            df['cross_{}_{}_count_ratio'.format(f, col)] = df['cross_{}_{}_count'.format(f, col)] / df[
                col + '_count']  # 比例偏好
        df['cross_{}_{}_nunique_ratio_{}_count'.format(f, col, f)] = df['cross_{}_{}_nunique'.format(f, col)] / df[
            f + '_count']
        print('runtime:', time.time() - t)
    df = reduce_mem(df)
del df['id']
gc.collect()
# Out:
# *************************** cross feat (second order) ***************************
# ------------------ deviceid newsid ------------------
# runtime: 140.0743055343628
# ------------------ deviceid pos ------------------
# runtime: 147.7860164642334
# ------------------ deviceid netmodel ------------------
# runtime: 156.31755542755127
# ------------------ deviceid lng_lat ------------------
# runtime: 165.10156059265137
# 781.91 Mb, 645.73 Mb (17.42 %)
# ------------------ newsid deviceid ------------------
# runtime: 454.40870666503906
# ------------------ newsid pos ------------------
# runtime: 742.6436910629272
# ------------------ newsid netmodel ------------------
# runtime: 1017.4372234344482
# ------------------ newsid lng_lat ------------------
# runtime: 1303.300873041153
# 801.37 Mb, 682.78 Mb (14.80 %)
# ------------------ pos deviceid ------------------
# runtime: 1308.1814727783203
# ------------------ pos newsid ------------------
# runtime: 1310.4886124134064
# ------------------ pos netmodel ------------------
# runtime: 1314.9467103481293
# ------------------ pos lng_lat ------------------
# runtime: 1319.6754019260406
# 816.19 Mb, 720.77 Mb (11.69 %)
# ------------------ netmodel deviceid ------------------
# runtime: 1326.1498703956604
# ------------------ netmodel newsid ------------------
# runtime: 1329.7287192344666
# ------------------ netmodel pos ------------------
# runtime: 1333.1798963546753
# ------------------ netmodel lng_lat ------------------
# runtime: 1340.2298040390015
# 831.94 Mb, 751.34 Mb (9.69 %)
# ------------------ lng_lat deviceid ------------------
# runtime: 1375.0547878742218
# ------------------ lng_lat newsid ------------------
# runtime: 1406.837670326233
# ------------------ lng_lat pos ------------------
# runtime: 1438.4525907039642
# ------------------ lng_lat netmodel ------------------
# runtime: 1471.1269760131836
# 840.28 Mb, 773.57 Mb (7.94 %)
# 0

# %%
df.to_pickle(path_pickle + "df_sample01_081_cross.pickle")
print("success build df_sample01_081_cross.pickle")

del sort_df
train_num
# Out:
# success build df_sample01_081_cross.pickle
# 734116

# %%
df =pd.read_pickle(path_pickle + "df_sample01_081_cross.pickle")

# %%
# train_num =11376681
cate_cols = [
    'deviceid', 'newsid', 'pos', 'app_version', 'device_vendor',
    'netmodel', 'osversion', 'device_version', 'lng', 'lat', 'lng_lat'
]

# %%
print('======================================== prepare train & valid  =============================================')
train_df = df[:train_num].reset_index(drop=True)
test_df = df[train_num:].reset_index(drop=True)
del df
gc.collect()

train_idx = train_df[train_df['day'] < 10].index.tolist()
val_idx = train_df[train_df['day'] == 10].index.tolist()

train_x = train_df.iloc[train_idx].reset_index(drop=True)
train_y = labels[train_idx]
val_x = train_df.iloc[val_idx].reset_index(drop=True)
val_y = labels[val_idx]

del train_x['day'], val_x['day'], train_df['day'], test_df['day']
gc.collect()
print('runtime:', time.time() - t)
print('========================================================================================================')
# Out:
# ======================================== prepare train & valid  =============================================
# runtime: 1481.3427867889404
# ========================================================================================================

# %%
print('=============================================== training validate ===============================================')
fea_imp_list = []
clf = LGBMClassifier(
    n_jobs=7,
    learning_rate=0.01,
    n_estimators=5000,
    num_leaves=255,
    subsample=0.9,
    colsample_bytree=0.8,
    random_state=2019,
    metric=None
)

print('************** training **************')
clf.fit(
    train_x, train_y,
    eval_set=[(val_x, val_y)],
    eval_metric='auc',
    categorical_feature=cate_cols,
    early_stopping_rounds=200,
    verbose=50
)
print('runtime:', time.time() - t)
# Out:
# =============================================== training validate ===============================================
# ************** training **************
# /home/ryan/anaconda3/envs/tensorflow/lib/python3.6/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['app_version', 'device_vendor', 'device_version', 'deviceid', 'lat', 'lng', 'lng_lat', 'netmodel', 'newsid', 'osversion', 'pos']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# Training until validation scores don't improve for 200 rounds
# [50]	valid_0's auc: 0.966111
# [100]	valid_0's auc: 0.967396
# [150]	valid_0's auc: 0.968283
# [200]	valid_0's auc: 0.968857
# [250]	valid_0's auc: 0.969554
# [300]	valid_0's auc: 0.969995
# [350]	valid_0's auc: 0.970615
# [400]	valid_0's auc: 0.971105
# [450]	valid_0's auc: 0.971563
# [500]	valid_0's auc: 0.97186
# [550]	valid_0's auc: 0.972066
# [600]	valid_0's auc: 0.97225
# [650]	valid_0's auc: 0.972352
# [700]	valid_0's auc: 0.972417
# [750]	valid_0's auc: 0.972431
# [800]	valid_0's auc: 0.972444
# [850]	valid_0's auc: 0.972444
# [900]	valid_0's auc: 0.972478
# [950]	valid_0's auc: 0.972455
# [1000]	valid_0's auc: 0.972458
# [1050]	valid_0's auc: 0.972457
# Early stopping, best iteration is:
# [896]	valid_0's auc: 0.972479
# runtime: 4915.117074012756

# %%
gc.collect()

print('************** validate predict **************')
best_rounds = clf.best_iteration_
best_auc = clf.best_score_['valid_0']['auc']
val_pred = clf.predict_proba(val_x)[:, 1]
fea_imp_list.append(clf.feature_importances_)
print('runtime:', time.time() - t)
# Out:
# ************** validate predict **************
# runtime: 4984.874499082565

# %%
print('=============================================== training predict ===============================================')
clf = LGBMClassifier(
    learning_rate=0.01,
    n_estimators=best_rounds,
    num_leaves=255,
    subsample=0.9,
    colsample_bytree=0.8,
    random_state=2019
)

# %%
print('************** training using all the data **************')
clf.fit(
    train_df, labels,
    eval_set=[(train_df, labels)],
    categorical_feature=cate_cols,
    verbose=50
)
print('runtime:', time.time() - t)

# %%
print('************** test predict **************')
# sub = pd.read_csv(path_data + 'sample.csv')

sub['target'] = clf.predict_proba(test_df)[:, 1]
fea_imp_list.append(clf.feature_importances_)
print('runtime:', time.time() - t)
# Out:
# ************** test predict **************
# runtime: 5134.657577991486

# %%
gc.collect()
# Out:
# 6

# %%
print('=============================================== feat importances ===============================================')
# 特征重要性可以好好看看
fea_imp_dict = dict(zip(train_df.columns.values, np.mean(fea_imp_list, axis=0)))
fea_imp_item = sorted(fea_imp_dict.items(), key=lambda x: x[1], reverse=True)
for f, imp in fea_imp_item:
    print('{} = {}'.format(f, imp))
# Out:
# =============================================== feat importances ===============================================
# deviceid = 29432.0
# device_version = 18247.0
# newsid = 8640.0
# lng = 8072.0
# lat = 7996.0
# lng_lat = 6657.0
# netmodel_deviceid_lng_lat_next1_exposure_ts_gap = 3749.0
# netmodel_deviceid_next1_exposure_ts_gap = 2886.0
# deviceid_next3_exposure_ts_gap = 2681.0
# pos_netmodel_deviceid_next1_exposure_ts_gap = 2377.0
# netmodel_deviceid_next3_exposure_ts_gap = 2259.0
# netmodel_deviceid_lng_lat_next2_exposure_ts_gap = 2122.0
# deviceid_lng_lat_next3_exposure_ts_gap = 2033.0
# deviceid_next1_exposure_ts_gap = 2030.0
# netmodel_deviceid_next2_exposure_ts_gap = 1988.0
# netmodel_deviceid_lng_lat_next3_exposure_ts_gap = 1763.0
# cross_deviceid_newsid_count = 1752.0
# netmodel_lng_lat_next1_exposure_ts_gap = 1745.0
# pos_netmodel_deviceid_lng_lat_next1_exposure_ts_gap = 1731.0
# cross_deviceid_pos_ent = 1655.0
# cross_lng_lat_pos_ent = 1642.0
# newsid_next1_exposure_ts_gap = 1584.0
# deviceid_next5_exposure_ts_gap = 1576.0
# pos_count = 1574.0
# deviceid_lng_lat_next1_exposure_ts_gap = 1567.0
# netmodel_deviceid_next5_exposure_ts_gap = 1559.0
# pos_newsid_next1_exposure_ts_gap = 1423.0
# deviceid_lng_lat_next5_exposure_ts_gap = 1303.0
# cross_pos_deviceid_count_ratio = 1276.0
# pos_deviceid_next1_exposure_ts_gap = 1250.0
# netmodel_lng_lat_next2_exposure_ts_gap = 1246.0
# newsid_prev1_exposure_ts_gap = 1195.0
# deviceid_next2_exposure_ts_gap = 1193.0
# netmodel_deviceid_next10_exposure_ts_gap = 1171.0
# netmodel_deviceid_lng_lat_next10_exposure_ts_gap = 1122.0
# lng_lat_next1_exposure_ts_gap = 1114.0
# cross_pos_lng_lat_count_ratio = 1111.0
# pos_netmodel_deviceid_prev1_exposure_ts_gap = 1049.0
# pos_deviceid_lng_lat_next1_exposure_ts_gap = 1019.0
# lng_lat_next3_exposure_ts_gap = 1014.0
# newsid_next2_exposure_ts_gap = 1013.0
# netmodel_deviceid_prev5_exposure_ts_gap = 1010.0
# netmodel_deviceid_prev10_exposure_ts_gap = 998.0
# deviceid_lng_lat_next2_exposure_ts_gap = 995.0
# netmodel_deviceid_lng_lat_next5_exposure_ts_gap = 995.0
# pos_deviceid_lng_lat_next2_exposure_ts_gap = 991.0
# deviceid_prev1_exposure_ts_gap = 980.0
# pos_netmodel_lng_lat_next1_exposure_ts_gap = 958.0
# netmodel_lng_lat_next3_exposure_ts_gap = 955.0
# netmodel_deviceid_prev1_exposure_ts_gap = 949.0
# pos_deviceid_next2_exposure_ts_gap = 923.0
# pos_netmodel_deviceid_next2_exposure_ts_gap = 916.0
# newsid_next3_exposure_ts_gap = 880.0
# netmodel_deviceid_lng_lat_prev1_exposure_ts_gap = 876.0
# cross_deviceid_pos_count_ratio = 856.0
# pos_netmodel_deviceid_lng_lat_next2_exposure_ts_gap = 847.0
# pos = 819.0
# deviceid_next10_exposure_ts_gap = 819.0
# lng_lat_next2_exposure_ts_gap = 816.0
# netmodel_deviceid_prev3_exposure_ts_gap = 814.0
# lng_lat_next5_exposure_ts_gap = 808.0
# cross_newsid_pos_ent = 799.0
# pos_netmodel_deviceid_next3_exposure_ts_gap = 793.0
# pos_newsid_prev1_exposure_ts_gap = 782.0
# deviceid_lng_lat_next10_exposure_ts_gap = 776.0
# netmodel_lng_lat_prev1_exposure_ts_gap = 775.0
# pos_netmodel_deviceid_prev2_exposure_ts_gap = 773.0
# pos_deviceid_next3_exposure_ts_gap = 769.0
# newsid_next5_exposure_ts_gap = 764.0
# deviceid_lng_lat_prev1_exposure_ts_gap = 755.0
# cross_pos_netmodel_count = 750.0
# lng_lat_prev1_exposure_ts_gap = 741.0
# newsid_prev2_exposure_ts_gap = 734.0
# pos_netmodel_deviceid_next5_exposure_ts_gap = 734.0
# pos_deviceid_prev2_exposure_ts_gap = 733.0
# pos_deviceid_next10_exposure_ts_gap = 730.0
# cross_lng_lat_pos_count_ratio = 722.0
# deviceid_prev10_exposure_ts_gap = 711.0
# pos_deviceid_prev10_exposure_ts_gap = 711.0
# pos_deviceid_prev1_exposure_ts_gap = 691.0
# pos_deviceid_prev_day_ctr = 676.0
# deviceid_prev2_exposure_ts_gap = 674.0
# netmodel_deviceid_prev2_exposure_ts_gap = 672.0
# netmodel_lng_lat_next10_exposure_ts_gap = 672.0
# pos_deviceid_next5_exposure_ts_gap = 668.0
# netmodel_lng_lat_prev5_exposure_ts_gap = 664.0
# cross_newsid_deviceid_nunique_ratio_newsid_count = 664.0
# pos_lng_lat_next1_exposure_ts_gap = 661.0
# pos_lng_lat_next2_exposure_ts_gap = 658.0
# pos_netmodel_lng_lat_prev1_exposure_ts_gap = 655.0
# netmodel_lng_lat_next5_exposure_ts_gap = 652.0
# pos_deviceid_prev5_exposure_ts_gap = 651.0
# deviceid_prev5_exposure_ts_gap = 649.0
# pos_deviceid_prev3_exposure_ts_gap = 647.0
# pos_netmodel_deviceid_prev5_exposure_ts_gap = 646.0
# pos_netmodel_deviceid_prev3_exposure_ts_gap = 643.0
# pos_newsid_next2_exposure_ts_gap = 640.0
# netmodel_deviceid_lng_lat_prev5_exposure_ts_gap = 630.0
# netmodel_lng_lat_prev2_exposure_ts_gap = 626.0
# netmodel_count = 625.0
# pos_netmodel_deviceid_next10_exposure_ts_gap = 625.0
# netmodel_deviceid_lng_lat_prev2_exposure_ts_gap = 620.0
# cross_newsid_pos_count_ratio = 613.0
# pos_lng_lat_prev1_exposure_ts_gap = 607.0
# netmodel_deviceid_lng_lat_prev3_exposure_ts_gap = 598.0
# newsid_next10_exposure_ts_gap = 594.0
# minute = 584.0
# lng_lat_prev3_exposure_ts_gap = 584.0
# cross_newsid_deviceid_count_ratio = 582.0
# cross_pos_netmodel_ent = 578.0
# pos_netmodel_deviceid_prev10_exposure_ts_gap = 570.0
# lng_lat_prev10_exposure_ts_gap = 567.0
# deviceid_prev3_exposure_ts_gap = 566.0
# netmodel_lng_lat_prev10_exposure_ts_gap = 566.0
# deviceid_lng_lat_prev2_exposure_ts_gap = 561.0
# lng_lat_prev2_exposure_ts_gap = 542.0
# deviceid_lng_lat_prev3_exposure_ts_gap = 539.0
# newsid_prev5_exposure_ts_gap = 538.0
# lng_lat_prev5_exposure_ts_gap = 537.0
# cross_netmodel_pos_count_ratio = 533.0
# cross_newsid_lng_lat_nunique_ratio_newsid_count = 532.0
# cross_pos_newsid_count_ratio = 529.0
# lng_lat_next10_exposure_ts_gap = 521.0
# netmodel_deviceid_lng_lat_prev10_exposure_ts_gap = 519.0
# pos_netmodel_deviceid_lng_lat_prev2_exposure_ts_gap = 518.0
# pos_netmodel_lng_lat_next2_exposure_ts_gap = 513.0
# pos_netmodel_lng_lat_next3_exposure_ts_gap = 512.0
# pos_deviceid_lng_lat_prev1_exposure_ts_gap = 506.0
# deviceid_lng_lat_prev5_exposure_ts_gap = 506.0
# pos_netmodel_deviceid_lng_lat_prev1_exposure_ts_gap = 503.0
# netmodel_lng_lat_prev3_exposure_ts_gap = 499.0
# pos_lng_lat_prev2_exposure_ts_gap = 494.0
# deviceid_lng_lat_prev10_exposure_ts_gap = 485.0
# pos_deviceid_lng_lat_prev5_exposure_ts_gap = 481.0
# cross_newsid_netmodel_ent = 476.0
# pos_netmodel_deviceid_lng_lat_prev3_exposure_ts_gap = 475.0
# newsid_prev3_exposure_ts_gap = 474.0
# pos_deviceid_lng_lat_prev2_exposure_ts_gap = 465.0
# pos_netmodel_lng_lat_prev2_exposure_ts_gap = 463.0
# pos_netmodel_lng_lat_prev5_exposure_ts_gap = 463.0
# pos_netmodel_deviceid_lng_lat_next3_exposure_ts_gap = 463.0
# cross_deviceid_pos_nunique_ratio_deviceid_count = 463.0
# pos_deviceid_lng_lat_next5_exposure_ts_gap = 459.0
# pos_deviceid_lng_lat_next3_exposure_ts_gap = 455.0
# cross_netmodel_newsid_count_ratio = 448.0
# pos_lng_lat_prev5_exposure_ts_gap = 438.0
# pos_lng_lat_next5_exposure_ts_gap = 437.0
# pos_newsid_next3_exposure_ts_gap = 434.0
# pos_lng_lat_prev3_exposure_ts_gap = 433.0
# pos_lng_lat_next3_exposure_ts_gap = 426.0
# pos_lng_lat_prev10_exposure_ts_gap = 424.0
# cross_deviceid_pos_count = 422.0
# cross_newsid_pos_nunique_ratio_newsid_count = 421.0
# pos_lng_lat_next10_exposure_ts_gap = 418.0
# pos_netmodel_lng_lat_prev3_exposure_ts_gap = 418.0
# cross_netmodel_deviceid_count_ratio = 413.0
# pos_netmodel_deviceid_lng_lat_next5_exposure_ts_gap = 412.0
# pos_netmodel_lng_lat_prev10_exposure_ts_gap = 411.0
# deviceid_prev_day_ctr = 408.0
# pos_deviceid_lng_lat_prev10_exposure_ts_gap = 407.0
# pos_deviceid_lng_lat_prev3_exposure_ts_gap = 404.0
# pos_netmodel_lng_lat_next5_exposure_ts_gap = 404.0
# pos_netmodel_lng_lat_next10_exposure_ts_gap = 399.0
# pos_netmodel_deviceid_lng_lat_prev5_exposure_ts_gap = 392.0
# pos_newsid_next5_exposure_ts_gap = 385.0
# pos_netmodel_deviceid_lng_lat_prev10_exposure_ts_gap = 382.0
# pos_newsid_prev2_exposure_ts_gap = 365.0
# cross_pos_lng_lat_nunique_ratio_pos_count = 363.0
# pos_netmodel_deviceid_lng_lat_next10_exposure_ts_gap = 355.0
# pos_deviceid_lng_lat_next10_exposure_ts_gap = 341.0
# device_version_count = 336.0
# cross_deviceid_pos_nunique = 334.0
# cross_netmodel_lng_lat_count_ratio = 321.0
# cross_deviceid_newsid_count_ratio = 315.0
# cross_lng_lat_newsid_count_ratio = 309.0
# cross_newsid_netmodel_nunique_ratio_newsid_count = 308.0
# cross_pos_deviceid_nunique = 290.0
# cross_lng_lat_netmodel_ent = 281.0
# cross_deviceid_netmodel_count = 279.0
# cross_newsid_lng_lat_count_ratio = 277.0
# cross_deviceid_lng_lat_nunique_ratio_deviceid_count = 263.0
# cross_deviceid_netmodel_count_ratio = 258.0
# cross_newsid_lng_lat_count = 251.0
# cross_lng_lat_pos_nunique_ratio_lng_lat_count = 249.0
# pos_deviceid_prev_day_count = 241.0
# newsid_prev10_exposure_ts_gap = 238.0
# cross_newsid_lng_lat_ent = 237.0
# cross_deviceid_netmodel_ent = 225.0
# pos_deviceid_prev_day_click_count = 221.0
# cross_deviceid_netmodel_nunique_ratio_deviceid_count = 221.0
# cross_newsid_netmodel_count_ratio = 219.0
# cross_deviceid_lng_lat_count = 217.0
# cross_pos_netmodel_count_ratio = 217.0
# cross_pos_deviceid_ent = 216.0
# cross_newsid_netmodel_count = 209.0
# hour = 206.0
# cross_pos_lng_lat_count = 200.0
# cross_deviceid_newsid_nunique_ratio_deviceid_count = 198.0
# cross_lng_lat_netmodel_count_ratio = 192.0
# pos_newsid_next10_exposure_ts_gap = 191.0
# cross_newsid_deviceid_ent = 191.0
# deviceid_prev_day_count = 185.0
# cross_lng_lat_pos_nunique = 182.0
# pos_newsid_prev3_exposure_ts_gap = 181.0
# cross_deviceid_lng_lat_ent = 176.0
# cross_lng_lat_deviceid_count_ratio = 175.0
# cross_netmodel_lng_lat_count = 164.0
# cross_newsid_pos_count = 163.0
# deviceid_prev_day_click_count = 149.0
# cross_deviceid_newsid_nunique = 149.0
# deviceid_count = 147.0
# newsid_count = 142.0
# pos_newsid_prev10_exposure_ts_gap = 142.0
# cross_pos_newsid_ent = 134.0
# pos_newsid_prev5_exposure_ts_gap = 133.0
# cross_lng_lat_deviceid_nunique_ratio_lng_lat_count = 132.0
# lat_count = 118.0
# cross_deviceid_lng_lat_nunique = 104.0
# lng_count = 99.0
# cross_deviceid_newsid_ent = 99.0
# cross_lng_lat_newsid_nunique_ratio_lng_lat_count = 91.0
# cross_lng_lat_netmodel_nunique_ratio_lng_lat_count = 84.0
# app_version_count = 82.0
# cross_newsid_lng_lat_nunique = 78.0
# device_vendor_count = 73.0
# osversion_count = 68.0
# cross_newsid_deviceid_nunique = 65.0
# cross_newsid_pos_nunique = 55.0
# cross_pos_deviceid_nunique_ratio_pos_count = 52.0
# cross_deviceid_lng_lat_count_ratio = 49.0
# cross_lng_lat_newsid_ent = 42.0
# cross_lng_lat_newsid_nunique = 32.0
# lng_lat_count = 21.0
# cross_pos_newsid_nunique_ratio_pos_count = 21.0
# cross_newsid_netmodel_nunique = 20.0
# cross_netmodel_deviceid_nunique = 19.0
# osversion = 17.0
# cross_pos_lng_lat_ent = 17.0
# cross_deviceid_netmodel_nunique = 9.0
# cross_netmodel_deviceid_ent = 7.0
# cross_pos_netmodel_nunique_ratio_pos_count = 6.0
# app_version = 4.0
# cross_lng_lat_netmodel_nunique = 4.0
# device_vendor = 3.0
# cross_pos_newsid_nunique = 2.0
# cross_lng_lat_deviceid_nunique = 2.0
# cross_netmodel_deviceid_nunique_ratio_netmodel_count = 1.0
# cross_lng_lat_deviceid_ent = 1.0
# netmodel = 0.0
# cross_pos_netmodel_nunique = 0.0
# cross_pos_lng_lat_nunique = 0.0
# cross_netmodel_newsid_nunique = 0.0
# cross_netmodel_newsid_ent = 0.0
# cross_netmodel_newsid_nunique_ratio_netmodel_count = 0.0
# cross_netmodel_pos_nunique = 0.0
# cross_netmodel_pos_ent = 0.0
# cross_netmodel_pos_nunique_ratio_netmodel_count = 0.0
# cross_netmodel_lng_lat_nunique = 0.0
# cross_netmodel_lng_lat_ent = 0.0
# cross_netmodel_lng_lat_nunique_ratio_netmodel_count = 0.0

# %%
print('=============================================== threshold search ===============================================')
# f1阈值敏感，所以对阈值做一个简单的迭代搜索。
t0 = 0.05
v = 0.002
best_t = t0
best_f1 = 0
for step in range(201):
    curr_t = t0 + step * v
    y = [1 if x >= curr_t else 0 for x in val_pred]
    curr_f1 = f1_score(val_y, y)
    if curr_f1 > best_f1:
        best_t = curr_t
        best_f1 = curr_f1
        print('step: {}   best threshold: {}   best f1: {}'.format(step, best_t, best_f1))
print('search finish.')

val_pred = [1 if x >= best_t else 0 for x in val_pred]
print('\nbest auc:', best_auc)
print('best f1:', f1_score(val_y, val_pred))
print('validate mean:', np.mean(val_pred))
print('runtime:', time.time() - t)
# Out:
# =============================================== threshold search ===============================================
# step: 0   best threshold: 0.05   best f1: 0.6979839444078625
# step: 1   best threshold: 0.052000000000000005   best f1: 0.7004941782702353
# step: 2   best threshold: 0.054000000000000006   best f1: 0.7026545166402536
# step: 3   best threshold: 0.056   best f1: 0.7047535111161654
# step: 4   best threshold: 0.058   best f1: 0.7067306319426597
# step: 5   best threshold: 0.060000000000000005   best f1: 0.708621901033825
# step: 6   best threshold: 0.062   best f1: 0.7109849903488806
# step: 7   best threshold: 0.064   best f1: 0.7127444174476455
# step: 8   best threshold: 0.066   best f1: 0.7143126751157761
# step: 9   best threshold: 0.068   best f1: 0.7160324700875876
# step: 10   best threshold: 0.07   best f1: 0.7174730435545932
# step: 11   best threshold: 0.07200000000000001   best f1: 0.718934867812633
# step: 12   best threshold: 0.07400000000000001   best f1: 0.7205986330426585
# step: 13   best threshold: 0.07600000000000001   best f1: 0.7218207345008498
# step: 14   best threshold: 0.078   best f1: 0.7231563028200338
# step: 15   best threshold: 0.08   best f1: 0.7244488083549049
# step: 16   best threshold: 0.082   best f1: 0.7256396866840731
# step: 17   best threshold: 0.084   best f1: 0.7270087414680876
# step: 18   best threshold: 0.08600000000000001   best f1: 0.7282502590595762
# step: 19   best threshold: 0.088   best f1: 0.7295673257932862
# step: 20   best threshold: 0.09   best f1: 0.7306309843839671
# step: 21   best threshold: 0.092   best f1: 0.7319170843238496
# step: 22   best threshold: 0.094   best f1: 0.7333566231754182
# step: 23   best threshold: 0.096   best f1: 0.7340064263633179
# step: 24   best threshold: 0.098   best f1: 0.735095192293012
# step: 25   best threshold: 0.1   best f1: 0.7363135333741581
# step: 26   best threshold: 0.10200000000000001   best f1: 0.7373269059535141
# step: 27   best threshold: 0.10400000000000001   best f1: 0.7381461703011742
# step: 28   best threshold: 0.10600000000000001   best f1: 0.7388413175962355
# step: 29   best threshold: 0.10800000000000001   best f1: 0.7397455124538105
# step: 30   best threshold: 0.11   best f1: 0.7409428434123428
# step: 31   best threshold: 0.112   best f1: 0.7419931314198691
# step: 32   best threshold: 0.114   best f1: 0.7429728887503896
# step: 33   best threshold: 0.116   best f1: 0.7438331355773434
# step: 34   best threshold: 0.11800000000000001   best f1: 0.7445390248482192
# step: 35   best threshold: 0.12000000000000001   best f1: 0.7450961945528953
# step: 36   best threshold: 0.12200000000000001   best f1: 0.7460477103435269
# step: 37   best threshold: 0.124   best f1: 0.7467124431075485
# step: 38   best threshold: 0.126   best f1: 0.7473717442778217
# step: 39   best threshold: 0.128   best f1: 0.7478370897587979
# step: 40   best threshold: 0.13   best f1: 0.7482016668251101
# step: 41   best threshold: 0.132   best f1: 0.7485907553551296
# step: 42   best threshold: 0.134   best f1: 0.7492204899777283
# step: 43   best threshold: 0.136   best f1: 0.7499521714176391
# step: 44   best threshold: 0.138   best f1: 0.7505989841229275
# step: 45   best threshold: 0.14   best f1: 0.7513366415879622
# step: 46   best threshold: 0.14200000000000002   best f1: 0.7518681248196016
# step: 47   best threshold: 0.14400000000000002   best f1: 0.7523979370511399
# step: 48   best threshold: 0.14600000000000002   best f1: 0.7528211071940245
# step: 49   best threshold: 0.14800000000000002   best f1: 0.7533100033866053
# step: 50   best threshold: 0.15000000000000002   best f1: 0.7537529288195847
# step: 51   best threshold: 0.15200000000000002   best f1: 0.7542681446718991
# step: 52   best threshold: 0.15400000000000003   best f1: 0.7547867252476451
# step: 53   best threshold: 0.156   best f1: 0.7552661068975037
# step: 54   best threshold: 0.158   best f1: 0.7556893045953639
# step: 55   best threshold: 0.16   best f1: 0.7561182259588751
# step: 56   best threshold: 0.162   best f1: 0.7567373455429868
# step: 57   best threshold: 0.164   best f1: 0.7570059841077792
# step: 58   best threshold: 0.166   best f1: 0.7576378081742977
# step: 59   best threshold: 0.168   best f1: 0.7583604082570313
# step: 60   best threshold: 0.16999999999999998   best f1: 0.7586433548047852
# step: 61   best threshold: 0.172   best f1: 0.7589441463976565
# step: 62   best threshold: 0.174   best f1: 0.7593789147491263
# step: 63   best threshold: 0.176   best f1: 0.7598184069335534
# step: 64   best threshold: 0.178   best f1: 0.7603215561730845
# step: 65   best threshold: 0.18   best f1: 0.7610258789224295
# step: 66   best threshold: 0.182   best f1: 0.7613755121676093
# step: 67   best threshold: 0.184   best f1: 0.7617607973421927
# step: 68   best threshold: 0.186   best f1: 0.7620568614729417
# step: 69   best threshold: 0.188   best f1: 0.7623396100649892
# step: 70   best threshold: 0.19   best f1: 0.7627344949596101
# step: 71   best threshold: 0.192   best f1: 0.7631477798760007
# step: 72   best threshold: 0.194   best f1: 0.7635785421374174
# step: 73   best threshold: 0.196   best f1: 0.7638430202343632
# step: 74   best threshold: 0.198   best f1: 0.7642980644944687
# step: 75   best threshold: 0.2   best f1: 0.7647474271877313
# step: 76   best threshold: 0.202   best f1: 0.7649178340517242
# step: 77   best threshold: 0.20400000000000001   best f1: 0.7653396732257575
# step: 78   best threshold: 0.20600000000000002   best f1: 0.7656405666908699
# step: 79   best threshold: 0.20800000000000002   best f1: 0.7656617236773134
# step: 80   best threshold: 0.21000000000000002   best f1: 0.7659934654906808
# step: 81   best threshold: 0.21200000000000002   best f1: 0.7664920400793449
# step: 82   best threshold: 0.21400000000000002   best f1: 0.7668386746333515
# step: 83   best threshold: 0.21600000000000003   best f1: 0.7669640581187867
# step: 84   best threshold: 0.21800000000000003   best f1: 0.7672827529868274
# step: 85   best threshold: 0.22000000000000003   best f1: 0.7677628216050434
# step: 86   best threshold: 0.22200000000000003   best f1: 0.7681649090474728
# step: 87   best threshold: 0.22400000000000003   best f1: 0.7682503886696394
# step: 88   best threshold: 0.22599999999999998   best f1: 0.7683018609742747
# step: 89   best threshold: 0.22799999999999998   best f1: 0.7684850560931746
# step: 90   best threshold: 0.22999999999999998   best f1: 0.7688612893265173
# step: 91   best threshold: 0.23199999999999998   best f1: 0.7690775123233087
# step: 92   best threshold: 0.23399999999999999   best f1: 0.7695906432748538
# step: 94   best threshold: 0.238   best f1: 0.7698991466252909
# step: 95   best threshold: 0.24   best f1: 0.7701230774542128
# step: 96   best threshold: 0.242   best f1: 0.7705867104467294
# step: 97   best threshold: 0.244   best f1: 0.77062569213732
# step: 98   best threshold: 0.246   best f1: 0.7709340402307812
# step: 99   best threshold: 0.248   best f1: 0.7711549803975991
# step: 105   best threshold: 0.26   best f1: 0.771216938611509
# step: 106   best threshold: 0.262   best f1: 0.7713106439539683
# step: 107   best threshold: 0.264   best f1: 0.7715936952714536
# step: 108   best threshold: 0.266   best f1: 0.7718203177052285
# step: 109   best threshold: 0.268   best f1: 0.7719483073465374
# step: 110   best threshold: 0.27   best f1: 0.7720433131767684
# step: 111   best threshold: 0.272   best f1: 0.7722176262475138
# step: 112   best threshold: 0.274   best f1: 0.7723571504106596
# step: 113   best threshold: 0.276   best f1: 0.7725379456406636
# step: 114   best threshold: 0.278   best f1: 0.7727457459403105
# step: 116   best threshold: 0.28200000000000003   best f1: 0.7727844401537562
# step: 117   best threshold: 0.28400000000000003   best f1: 0.7728651237031126
# step: 118   best threshold: 0.28600000000000003   best f1: 0.7729621278031285
# step: 119   best threshold: 0.28800000000000003   best f1: 0.773032748995484
# step: 120   best threshold: 0.29   best f1: 0.7731852326533517
# step: 130   best threshold: 0.31   best f1: 0.7731878971146751
# step: 131   best threshold: 0.312   best f1: 0.773197362257216
# step: 135   best threshold: 0.32   best f1: 0.7732797916214457
# step: 136   best threshold: 0.322   best f1: 0.7734284472769408
# step: 145   best threshold: 0.33999999999999997   best f1: 0.7735369886540114
# step: 146   best threshold: 0.34199999999999997   best f1: 0.7736118223717902
# step: 149   best threshold: 0.348   best f1: 0.7736891368583333
# search finish.
#
# best auc: 0.9724794667703146
# best f1: 0.7736891368583333
# validate mean: 0.10427252394333887
# runtime: 5213.824611902237

# %%
print('=============================================== sub save ===============================================')
sub.to_csv('sub_prob_{}_{}_{}.csv'.format(best_auc, best_f1, sub['target'].mean()), index=False)
sub['target'] = sub['target'].apply(lambda x: 1 if x >= best_t else 0)
sub.to_csv('sub_{}_{}_{}.csv'.format(best_auc, best_f1, sub['target'].mean()), index=False)
print('runtime:', time.time() - t)
print('finish.')
print('========================================================================================================')

# %%
## 开始预测全量数据

# %%
if debug_small:
    train_df = pd.read_pickle(path_pickle + 'train_small.pickle')
    test_df = pd.read_pickle(path_pickle + 'test_small.pickle')

    # app = pd.read_pickle(path_pickle + 'app_small.pickle')
    # user = pd.read_pickle(path_pickle + 'user_small.pickle')
else:
    train_df = pd.read_pickle(path_pickle + 'train.pickle')
    test_df = pd.read_pickle(path_pickle + 'test.pickle')
    sub = pd.read_csv(path_data + 'sample.csv')

    # app = pd.read_pickle(path_pickle + 'app.pickle')
    # user = pd.read_pickle(path_pickle + 'user.pickle')

# %%
print('=============================================== read train ===============================================')
t = time.time()

train_num = train_df.shape[0]
labels = train_df['target'].values
print('runtime:', time.time() - t)
# Out:
# =============================================== read train ===============================================
# runtime: 21.906771421432495

# %%
df =pd.read_pickle(path_pickle + "df_081_cross.pickle")

# %%
miss_cols = ['cross_deviceid_newsid_nunique_x', 'cross_deviceid_newsid_ent_x', 'cross_deviceid_pos_nunique_x', 'cross_deviceid_pos_ent_x', 'cross_deviceid_newsid_nunique_y', 'cross_deviceid_newsid_ent_y', 'cross_deviceid_pos_nunique_y', 'cross_deviceid_pos_ent_y']
for mis in miss_cols:
    del df[mis]

# %%
print('======================================== prepare train & valid  =============================================')
train_df = df[:train_num].reset_index(drop=True)
test_df = df[train_num:].reset_index(drop=True)
del df
gc.collect()

train_idx = train_df[train_df['day'] < 10].index.tolist()
val_idx = train_df[train_df['day'] == 10].index.tolist()

train_x = train_df.iloc[train_idx].reset_index(drop=True)
train_y = labels[train_idx]
val_x = train_df.iloc[val_idx].reset_index(drop=True)
val_y = labels[val_idx]

del train_x['day'], val_x['day'], train_df['day'], test_df['day']
gc.collect()
print('runtime:', time.time() - t)
print('========================================================================================================')
# Out:
# ======================================== prepare train & valid  =============================================
# runtime: 1823.8565957546234
# ========================================================================================================

# %%
df_2 =pd.read_pickle(path_pickle + "df_sample01_081_cross.pickle")

# %%
gc.collect()

print('************** validate predict **************')
best_rounds = clf.best_iteration_
best_auc = clf.best_score_['valid_0']['auc']
val_pred = clf.predict_proba(val_x)[:, 1]
fea_imp_list.append(clf.feature_importances_)
print('runtime:', time.time() - t)
# Out:
# ************** validate predict **************
# runtime: 2352.062028646469

# %%
# df_2.columns.values
# Out:
# array(['deviceid', 'newsid', 'pos', 'app_version', 'device_vendor',
#        'netmodel', 'osversion', 'lng', 'lat', 'device_version', 'day',
#        'hour', 'minute', 'lng_lat', 'deviceid_count', 'newsid_count',
#        'pos_count', 'app_version_count', 'device_vendor_count',
#        'netmodel_count', 'osversion_count', 'device_version_count',
#        'lng_count', 'lat_count', 'lng_lat_count',
#        'deviceid_prev_day_click_count', 'deviceid_prev_day_count',
#        'deviceid_prev_day_ctr', 'pos_deviceid_prev_day_click_count',
#        'pos_deviceid_prev_day_count', 'pos_deviceid_prev_day_ctr',
#        'deviceid_prev1_exposure_ts_gap', 'deviceid_next1_exposure_ts_gap',
#        'deviceid_prev2_exposure_ts_gap', 'deviceid_next2_exposure_ts_gap',
#        'deviceid_prev3_exposure_ts_gap', 'deviceid_next3_exposure_ts_gap',
#        'deviceid_prev5_exposure_ts_gap', 'deviceid_next5_exposure_ts_gap',
#        'deviceid_prev10_exposure_ts_gap',
#        'deviceid_next10_exposure_ts_gap', 'newsid_prev1_exposure_ts_gap',
#        'newsid_next1_exposure_ts_gap', 'newsid_prev2_exposure_ts_gap',
#        'newsid_next2_exposure_ts_gap', 'newsid_prev3_exposure_ts_gap',
#        'newsid_next3_exposure_ts_gap', 'newsid_prev5_exposure_ts_gap',
#        'newsid_next5_exposure_ts_gap', 'newsid_prev10_exposure_ts_gap',
#        'newsid_next10_exposure_ts_gap', 'lng_lat_prev1_exposure_ts_gap',
#        'lng_lat_next1_exposure_ts_gap', 'lng_lat_prev2_exposure_ts_gap',
#        'lng_lat_next2_exposure_ts_gap', 'lng_lat_prev3_exposure_ts_gap',
#        'lng_lat_next3_exposure_ts_gap', 'lng_lat_prev5_exposure_ts_gap',
#        'lng_lat_next5_exposure_ts_gap', 'lng_lat_prev10_exposure_ts_gap',
#        'lng_lat_next10_exposure_ts_gap',
#        'pos_deviceid_prev1_exposure_ts_gap',
#        'pos_deviceid_next1_exposure_ts_gap',
#        'pos_deviceid_prev2_exposure_ts_gap',
#        'pos_deviceid_next2_exposure_ts_gap',
#        'pos_deviceid_prev3_exposure_ts_gap',
#        'pos_deviceid_next3_exposure_ts_gap',
#        'pos_deviceid_prev5_exposure_ts_gap',
#        'pos_deviceid_next5_exposure_ts_gap',
#        'pos_deviceid_prev10_exposure_ts_gap',
#        'pos_deviceid_next10_exposure_ts_gap',
#        'pos_newsid_prev1_exposure_ts_gap',
#        'pos_newsid_next1_exposure_ts_gap',
#        'pos_newsid_prev2_exposure_ts_gap',
#        'pos_newsid_next2_exposure_ts_gap',
#        'pos_newsid_prev3_exposure_ts_gap',
#        'pos_newsid_next3_exposure_ts_gap',
#        'pos_newsid_prev5_exposure_ts_gap',
#        'pos_newsid_next5_exposure_ts_gap',
#        'pos_newsid_prev10_exposure_ts_gap',
#        'pos_newsid_next10_exposure_ts_gap',
#        'pos_lng_lat_prev1_exposure_ts_gap',
#        'pos_lng_lat_next1_exposure_ts_gap',
#        'pos_lng_lat_prev2_exposure_ts_gap',
#        'pos_lng_lat_next2_exposure_ts_gap',
#        'pos_lng_lat_prev3_exposure_ts_gap',
#        'pos_lng_lat_next3_exposure_ts_gap',
#        'pos_lng_lat_prev5_exposure_ts_gap',
#        'pos_lng_lat_next5_exposure_ts_gap',
#        'pos_lng_lat_prev10_exposure_ts_gap',
#        'pos_lng_lat_next10_exposure_ts_gap',
#        'pos_deviceid_lng_lat_prev1_exposure_ts_gap',
#        'pos_deviceid_lng_lat_next1_exposure_ts_gap',
#        'pos_deviceid_lng_lat_prev2_exposure_ts_gap',
#        'pos_deviceid_lng_lat_next2_exposure_ts_gap',
#        'pos_deviceid_lng_lat_prev3_exposure_ts_gap',
#        'pos_deviceid_lng_lat_next3_exposure_ts_gap',
#        'pos_deviceid_lng_lat_prev5_exposure_ts_gap',
#        'pos_deviceid_lng_lat_next5_exposure_ts_gap',
#        'pos_deviceid_lng_lat_prev10_exposure_ts_gap',
#        'pos_deviceid_lng_lat_next10_exposure_ts_gap',
#        'netmodel_deviceid_prev1_exposure_ts_gap',
#        'netmodel_deviceid_next1_exposure_ts_gap',
#        'netmodel_deviceid_prev2_exposure_ts_gap',
#        'netmodel_deviceid_next2_exposure_ts_gap',
#        'netmodel_deviceid_prev3_exposure_ts_gap',
#        'netmodel_deviceid_next3_exposure_ts_gap',
#        'netmodel_deviceid_prev5_exposure_ts_gap',
#        'netmodel_deviceid_next5_exposure_ts_gap',
#        'netmodel_deviceid_prev10_exposure_ts_gap',
#        'netmodel_deviceid_next10_exposure_ts_gap',
#        'pos_netmodel_deviceid_prev1_exposure_ts_gap',
#        'pos_netmodel_deviceid_next1_exposure_ts_gap',
#        'pos_netmodel_deviceid_prev2_exposure_ts_gap',
#        'pos_netmodel_deviceid_next2_exposure_ts_gap',
#        'pos_netmodel_deviceid_prev3_exposure_ts_gap',
#        'pos_netmodel_deviceid_next3_exposure_ts_gap',
#        'pos_netmodel_deviceid_prev5_exposure_ts_gap',
#        'pos_netmodel_deviceid_next5_exposure_ts_gap',
#        'pos_netmodel_deviceid_prev10_exposure_ts_gap',
#        'pos_netmodel_deviceid_next10_exposure_ts_gap',
#        'netmodel_lng_lat_prev1_exposure_ts_gap',
#        'netmodel_lng_lat_next1_exposure_ts_gap',
#        'netmodel_lng_lat_prev2_exposure_ts_gap',
#        'netmodel_lng_lat_next2_exposure_ts_gap',
#        'netmodel_lng_lat_prev3_exposure_ts_gap',
#        'netmodel_lng_lat_next3_exposure_ts_gap',
#        'netmodel_lng_lat_prev5_exposure_ts_gap',
#        'netmodel_lng_lat_next5_exposure_ts_gap',
#        'netmodel_lng_lat_prev10_exposure_ts_gap',
#        'netmodel_lng_lat_next10_exposure_ts_gap',
#        'deviceid_lng_lat_prev1_exposure_ts_gap',
#        'deviceid_lng_lat_next1_exposure_ts_gap',
#        'deviceid_lng_lat_prev2_exposure_ts_gap',
#        'deviceid_lng_lat_next2_exposure_ts_gap',
#        'deviceid_lng_lat_prev3_exposure_ts_gap',
#        'deviceid_lng_lat_next3_exposure_ts_gap',
#        'deviceid_lng_lat_prev5_exposure_ts_gap',
#        'deviceid_lng_lat_next5_exposure_ts_gap',
#        'deviceid_lng_lat_prev10_exposure_ts_gap',
#        'deviceid_lng_lat_next10_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_prev1_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_next1_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_prev2_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_next2_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_prev3_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_next3_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_prev5_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_next5_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_prev10_exposure_ts_gap',
#        'netmodel_deviceid_lng_lat_next10_exposure_ts_gap',
#        'pos_netmodel_lng_lat_prev1_exposure_ts_gap',
#        'pos_netmodel_lng_lat_next1_exposure_ts_gap',
#        'pos_netmodel_lng_lat_prev2_exposure_ts_gap',
#        'pos_netmodel_lng_lat_next2_exposure_ts_gap',
#        'pos_netmodel_lng_lat_prev3_exposure_ts_gap',
#        'pos_netmodel_lng_lat_next3_exposure_ts_gap',
#        'pos_netmodel_lng_lat_prev5_exposure_ts_gap',
#        'pos_netmodel_lng_lat_next5_exposure_ts_gap',
#        'pos_netmodel_lng_lat_prev10_exposure_ts_gap',
#        'pos_netmodel_lng_lat_next10_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_prev1_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_next1_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_prev2_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_next2_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_prev3_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_next3_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_prev5_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_next5_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_prev10_exposure_ts_gap',
#        'pos_netmodel_deviceid_lng_lat_next10_exposure_ts_gap',
#        'cross_deviceid_newsid_nunique', 'cross_deviceid_newsid_ent',
#        'cross_deviceid_newsid_count', 'cross_newsid_deviceid_count_ratio',
#        'cross_deviceid_newsid_count_ratio',
#        'cross_deviceid_newsid_nunique_ratio_deviceid_count',
#        'cross_deviceid_pos_nunique', 'cross_deviceid_pos_ent',
#        'cross_deviceid_pos_count', 'cross_pos_deviceid_count_ratio',
#        'cross_deviceid_pos_count_ratio',
#        'cross_deviceid_pos_nunique_ratio_deviceid_count',
#        'cross_deviceid_netmodel_nunique', 'cross_deviceid_netmodel_ent',
#        'cross_deviceid_netmodel_count',
#        'cross_netmodel_deviceid_count_ratio',
#        'cross_deviceid_netmodel_count_ratio',
#        'cross_deviceid_netmodel_nunique_ratio_deviceid_count',
#        'cross_deviceid_lng_lat_nunique', 'cross_deviceid_lng_lat_ent',
#        'cross_deviceid_lng_lat_count',
#        'cross_lng_lat_deviceid_count_ratio',
#        'cross_deviceid_lng_lat_count_ratio',
#        'cross_deviceid_lng_lat_nunique_ratio_deviceid_count',
#        'cross_newsid_deviceid_nunique', 'cross_newsid_deviceid_ent',
#        'cross_newsid_deviceid_nunique_ratio_newsid_count',
#        'cross_newsid_pos_nunique', 'cross_newsid_pos_ent',
#        'cross_newsid_pos_count', 'cross_pos_newsid_count_ratio',
#        'cross_newsid_pos_count_ratio',
#        'cross_newsid_pos_nunique_ratio_newsid_count',
#        'cross_newsid_netmodel_nunique', 'cross_newsid_netmodel_ent',
#        'cross_newsid_netmodel_count', 'cross_netmodel_newsid_count_ratio',
#        'cross_newsid_netmodel_count_ratio',
#        'cross_newsid_netmodel_nunique_ratio_newsid_count',
#        'cross_newsid_lng_lat_nunique', 'cross_newsid_lng_lat_ent',
#        'cross_newsid_lng_lat_count', 'cross_lng_lat_newsid_count_ratio',
#        'cross_newsid_lng_lat_count_ratio',
#        'cross_newsid_lng_lat_nunique_ratio_newsid_count',
#        'cross_pos_deviceid_nunique', 'cross_pos_deviceid_ent',
#        'cross_pos_deviceid_nunique_ratio_pos_count',
#        'cross_pos_newsid_nunique', 'cross_pos_newsid_ent',
#        'cross_pos_newsid_nunique_ratio_pos_count',
#        'cross_pos_netmodel_nunique', 'cross_pos_netmodel_ent',
#        'cross_pos_netmodel_count', 'cross_netmodel_pos_count_ratio',
#        'cross_pos_netmodel_count_ratio',
#        'cross_pos_netmodel_nunique_ratio_pos_count',
#        'cross_pos_lng_lat_nunique', 'cross_pos_lng_lat_ent',
#        'cross_pos_lng_lat_count', 'cross_lng_lat_pos_count_ratio',
#        'cross_pos_lng_lat_count_ratio',
#        'cross_pos_lng_lat_nunique_ratio_pos_count',
#        'cross_netmodel_deviceid_nunique', 'cross_netmodel_deviceid_ent',
#        'cross_netmodel_deviceid_nunique_ratio_netmodel_count',
#        'cross_netmodel_newsid_nunique', 'cross_netmodel_newsid_ent',
#        'cross_netmodel_newsid_nunique_ratio_netmodel_count',
#        'cross_netmodel_pos_nunique', 'cross_netmodel_pos_ent',
#        'cross_netmodel_pos_nunique_ratio_netmodel_count',
#        'cross_netmodel_lng_lat_nunique', 'cross_netmodel_lng_lat_ent',
#        'cross_netmodel_lng_lat_count',
#        'cross_lng_lat_netmodel_count_ratio',
#        'cross_netmodel_lng_lat_count_ratio',
#        'cross_netmodel_lng_lat_nunique_ratio_netmodel_count',
#        'cross_lng_lat_deviceid_nunique', 'cross_lng_lat_deviceid_ent',
#        'cross_lng_lat_deviceid_nunique_ratio_lng_lat_count',
#        'cross_lng_lat_newsid_nunique', 'cross_lng_lat_newsid_ent',
#        'cross_lng_lat_newsid_nunique_ratio_lng_lat_count',
#        'cross_lng_lat_pos_nunique', 'cross_lng_lat_pos_ent',
#        'cross_lng_lat_pos_nunique_ratio_lng_lat_count',
#        'cross_lng_lat_netmodel_nunique', 'cross_lng_lat_netmodel_ent',
#        'cross_lng_lat_netmodel_nunique_ratio_lng_lat_count'], dtype=object)

# %%
# miss_cols =[]
# for col in df.columns.values:
#     if col not in df_2.columns.values:
#         miss_cols.append(col)
# print(miss_cols)
# Out:
# []

# %%
# df[miss_cols].head(5)
# Out:
#    cross_deviceid_newsid_nunique_x  cross_deviceid_newsid_ent_x  \
# 0                                6                     1.735352
# 1                                6                     1.735352
# 2                               19                     2.945312
# 3                               19                     2.945312
# 4                               40                     3.634766
#
#    cross_deviceid_pos_nunique_x  cross_deviceid_pos_ent_x  \
# 0                             3                  0.995117
# 1                             3                  0.995117
# 2                             3                  1.086914
# 3                             3                  1.086914
# 4                             5                  1.234375
#
#    cross_deviceid_newsid_nunique_y  cross_deviceid_newsid_ent_y  \
# 0                                6                     1.735352
# 1                                6                     1.735352
# 2                               19                     2.945312
# 3                               19                     2.945312
# 4                               40                     3.634766
#
#    cross_deviceid_pos_nunique_y  cross_deviceid_pos_ent_y
# 0                             3                  0.995117
# 1                             3                  0.995117
# 2                             3                  1.086914
# 3                             3                  1.086914
# 4                             5                  1.234375

# %%
print('=============================================== training predict ===============================================')
clf = LGBMClassifier(
    learning_rate=0.01,
    n_estimators=best_rounds,
    num_leaves=255,
    subsample=0.9,
    colsample_bytree=0.8,
    random_state=2019
)
# Out:
# =============================================== training predict ===============================================

# %%
print('************** training using all the data **************')
clf.fit(
    train_df, labels,
    eval_set=[(train_df, labels)],
    categorical_feature=cate_cols,
    verbose=50
)
print('runtime:', time.time() - t)
# Out:
# ************** training using all the data **************
# /home/ryan/anaconda3/envs/tensorflow/lib/python3.6/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['app_version', 'device_vendor', 'device_version', 'deviceid', 'lat', 'lng', 'lng_lat', 'netmodel', 'newsid', 'osversion', 'pos']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# [50]	training's binary_logloss: 0.211156
# [100]	training's binary_logloss: 0.166179
# [150]	training's binary_logloss: 0.143335
# [200]	training's binary_logloss: 0.129926
# [250]	training's binary_logloss: 0.121307
# [300]	training's binary_logloss: 0.115278
# [350]	training's binary_logloss: 0.110885
# [400]	training's binary_logloss: 0.107303
# [450]	training's binary_logloss: 0.104661
# [500]	training's binary_logloss: 0.102335
# [550]	training's binary_logloss: 0.100249
# [600]	training's binary_logloss: 0.0983435
# [650]	training's binary_logloss: 0.0967053
# [700]	training's binary_logloss: 0.0952016
# [750]	training's binary_logloss: 0.0938171
# [800]	training's binary_logloss: 0.0925661
# [850]	training's binary_logloss: 0.0914056
# runtime: 13965.7793571949

# %%
print('************** test predict **************')
# sub = pd.read_csv(path_data + 'sample.csv')

sub['target'] = clf.predict_proba(test_df)[:, 1]
fea_imp_list.append(clf.feature_importances_)
print('runtime:', time.time() - t)
# Out:
# ************** test predict **************
# runtime: 3522.3794405460358

# %%
print('=============================================== feat importances ===============================================')
# 特征重要性可以好好看看
fea_imp_dict = dict(zip(train_df.columns.values, np.mean(fea_imp_list, axis=0)))
fea_imp_item = sorted(fea_imp_dict.items(), key=lambda x: x[1], reverse=True)
for f, imp in fea_imp_item:
    print('{} = {}'.format(f, imp))
# Out:
# =============================================== feat importances ===============================================
# deviceid = 29432.0
# device_version = 18247.0
# newsid = 8640.0
# lng = 8072.0
# lat = 7996.0
# lng_lat = 6657.0
# netmodel_deviceid_lng_lat_next1_exposure_ts_gap = 3749.0
# netmodel_deviceid_next1_exposure_ts_gap = 2886.0
# deviceid_next3_exposure_ts_gap = 2681.0
# pos_netmodel_deviceid_next1_exposure_ts_gap = 2377.0
# netmodel_deviceid_next3_exposure_ts_gap = 2259.0
# netmodel_deviceid_lng_lat_next2_exposure_ts_gap = 2122.0
# deviceid_lng_lat_next3_exposure_ts_gap = 2033.0
# deviceid_next1_exposure_ts_gap = 2030.0
# netmodel_deviceid_next2_exposure_ts_gap = 1988.0
# netmodel_deviceid_lng_lat_next3_exposure_ts_gap = 1763.0
# cross_deviceid_newsid_count_ratio = 1752.0
# netmodel_lng_lat_next1_exposure_ts_gap = 1745.0
# pos_netmodel_deviceid_lng_lat_next1_exposure_ts_gap = 1731.0
# cross_deviceid_pos_nunique_ratio_deviceid_count = 1655.0
# cross_lng_lat_pos_ent = 1642.0
# newsid_next1_exposure_ts_gap = 1584.0
# deviceid_next5_exposure_ts_gap = 1576.0
# pos_count = 1574.0
# deviceid_lng_lat_next1_exposure_ts_gap = 1567.0
# netmodel_deviceid_next5_exposure_ts_gap = 1559.0
# pos_newsid_next1_exposure_ts_gap = 1423.0
# deviceid_lng_lat_next5_exposure_ts_gap = 1303.0
# cross_deviceid_netmodel_ent = 1276.0
# pos_deviceid_next1_exposure_ts_gap = 1250.0
# netmodel_lng_lat_next2_exposure_ts_gap = 1246.0
# newsid_prev1_exposure_ts_gap = 1195.0
# deviceid_next2_exposure_ts_gap = 1193.0
# netmodel_deviceid_next10_exposure_ts_gap = 1171.0
# netmodel_deviceid_lng_lat_next10_exposure_ts_gap = 1122.0
# lng_lat_next1_exposure_ts_gap = 1114.0
# cross_pos_lng_lat_count_ratio = 1111.0
# pos_netmodel_deviceid_prev1_exposure_ts_gap = 1049.0
# pos_deviceid_lng_lat_next1_exposure_ts_gap = 1019.0
# lng_lat_next3_exposure_ts_gap = 1014.0
# newsid_next2_exposure_ts_gap = 1013.0
# netmodel_deviceid_prev5_exposure_ts_gap = 1010.0
# netmodel_deviceid_prev10_exposure_ts_gap = 998.0
# deviceid_lng_lat_next2_exposure_ts_gap = 995.0
# netmodel_deviceid_lng_lat_next5_exposure_ts_gap = 995.0
# pos_deviceid_lng_lat_next2_exposure_ts_gap = 991.0
# deviceid_prev1_exposure_ts_gap = 980.0
# pos_netmodel_lng_lat_next1_exposure_ts_gap = 958.0
# netmodel_lng_lat_next3_exposure_ts_gap = 955.0
# netmodel_deviceid_prev1_exposure_ts_gap = 949.0
# pos_deviceid_next2_exposure_ts_gap = 923.0
# pos_netmodel_deviceid_next2_exposure_ts_gap = 916.0
# newsid_next3_exposure_ts_gap = 880.0
# netmodel_deviceid_lng_lat_prev1_exposure_ts_gap = 876.0
# cross_deviceid_netmodel_count = 856.0
# pos_netmodel_deviceid_lng_lat_next2_exposure_ts_gap = 847.0
# pos = 819.0
# deviceid_next10_exposure_ts_gap = 819.0
# lng_lat_next2_exposure_ts_gap = 816.0
# netmodel_deviceid_prev3_exposure_ts_gap = 814.0
# lng_lat_next5_exposure_ts_gap = 808.0
# cross_newsid_pos_ent = 799.0
# pos_netmodel_deviceid_next3_exposure_ts_gap = 793.0
# pos_newsid_prev1_exposure_ts_gap = 782.0
# deviceid_lng_lat_next10_exposure_ts_gap = 776.0
# netmodel_lng_lat_prev1_exposure_ts_gap = 775.0
# pos_netmodel_deviceid_prev2_exposure_ts_gap = 773.0
# pos_deviceid_next3_exposure_ts_gap = 769.0
# newsid_next5_exposure_ts_gap = 764.0
# deviceid_lng_lat_prev1_exposure_ts_gap = 755.0
# cross_pos_netmodel_count = 750.0
# lng_lat_prev1_exposure_ts_gap = 741.0
# newsid_prev2_exposure_ts_gap = 734.0
# pos_netmodel_deviceid_next5_exposure_ts_gap = 734.0
# pos_deviceid_prev2_exposure_ts_gap = 733.0
# pos_deviceid_next10_exposure_ts_gap = 730.0
# cross_lng_lat_pos_count_ratio = 722.0
# deviceid_prev10_exposure_ts_gap = 711.0
# pos_deviceid_prev10_exposure_ts_gap = 711.0
# pos_deviceid_prev1_exposure_ts_gap = 691.0
# pos_deviceid_prev_day_ctr = 676.0
# deviceid_prev2_exposure_ts_gap = 674.0
# netmodel_deviceid_prev2_exposure_ts_gap = 672.0
# netmodel_lng_lat_next10_exposure_ts_gap = 672.0
# pos_deviceid_next5_exposure_ts_gap = 668.0
# netmodel_lng_lat_prev5_exposure_ts_gap = 664.0
# cross_newsid_deviceid_nunique_ratio_newsid_count = 664.0
# pos_lng_lat_next1_exposure_ts_gap = 661.0
# pos_lng_lat_next2_exposure_ts_gap = 658.0
# pos_netmodel_lng_lat_prev1_exposure_ts_gap = 655.0
# netmodel_lng_lat_next5_exposure_ts_gap = 652.0
# pos_deviceid_prev5_exposure_ts_gap = 651.0
# deviceid_prev5_exposure_ts_gap = 649.0
# pos_deviceid_prev3_exposure_ts_gap = 647.0
# pos_netmodel_deviceid_prev5_exposure_ts_gap = 646.0
# pos_netmodel_deviceid_prev3_exposure_ts_gap = 643.0
# pos_newsid_next2_exposure_ts_gap = 640.0
# netmodel_deviceid_lng_lat_prev5_exposure_ts_gap = 630.0
# netmodel_lng_lat_prev2_exposure_ts_gap = 626.0
# netmodel_count = 625.0
# pos_netmodel_deviceid_next10_exposure_ts_gap = 625.0
# netmodel_deviceid_lng_lat_prev2_exposure_ts_gap = 620.0
# cross_newsid_pos_count_ratio = 613.0
# pos_lng_lat_prev1_exposure_ts_gap = 607.0
# netmodel_deviceid_lng_lat_prev3_exposure_ts_gap = 598.0
# newsid_next10_exposure_ts_gap = 594.0
# minute = 584.0
# lng_lat_prev3_exposure_ts_gap = 584.0
# cross_deviceid_newsid_nunique_ratio_deviceid_count = 582.0
# cross_pos_netmodel_ent = 578.0
# pos_netmodel_deviceid_prev10_exposure_ts_gap = 570.0
# lng_lat_prev10_exposure_ts_gap = 567.0
# deviceid_prev3_exposure_ts_gap = 566.0
# netmodel_lng_lat_prev10_exposure_ts_gap = 566.0
# deviceid_lng_lat_prev2_exposure_ts_gap = 561.0
# lng_lat_prev2_exposure_ts_gap = 542.0
# deviceid_lng_lat_prev3_exposure_ts_gap = 539.0
# newsid_prev5_exposure_ts_gap = 538.0
# lng_lat_prev5_exposure_ts_gap = 537.0
# cross_netmodel_pos_count_ratio = 533.0
# cross_newsid_lng_lat_nunique_ratio_newsid_count = 532.0
# cross_pos_newsid_count_ratio = 529.0
# lng_lat_next10_exposure_ts_gap = 521.0
# netmodel_deviceid_lng_lat_prev10_exposure_ts_gap = 519.0
# pos_netmodel_deviceid_lng_lat_prev2_exposure_ts_gap = 518.0
# pos_netmodel_lng_lat_next2_exposure_ts_gap = 513.0
# pos_netmodel_lng_lat_next3_exposure_ts_gap = 512.0
# pos_deviceid_lng_lat_prev1_exposure_ts_gap = 506.0
# deviceid_lng_lat_prev5_exposure_ts_gap = 506.0
# pos_netmodel_deviceid_lng_lat_prev1_exposure_ts_gap = 503.0
# netmodel_lng_lat_prev3_exposure_ts_gap = 499.0
# pos_lng_lat_prev2_exposure_ts_gap = 494.0
# deviceid_lng_lat_prev10_exposure_ts_gap = 485.0
# pos_deviceid_lng_lat_prev5_exposure_ts_gap = 481.0
# cross_newsid_netmodel_ent = 476.0
# pos_netmodel_deviceid_lng_lat_prev3_exposure_ts_gap = 475.0
# newsid_prev3_exposure_ts_gap = 474.0
# pos_deviceid_lng_lat_prev2_exposure_ts_gap = 465.0
# pos_netmodel_lng_lat_prev2_exposure_ts_gap = 463.0
# pos_netmodel_lng_lat_prev5_exposure_ts_gap = 463.0
# pos_netmodel_deviceid_lng_lat_next3_exposure_ts_gap = 463.0
# cross_netmodel_deviceid_count_ratio = 463.0
# pos_deviceid_lng_lat_next5_exposure_ts_gap = 459.0
# pos_deviceid_lng_lat_next3_exposure_ts_gap = 455.0
# cross_netmodel_newsid_count_ratio = 448.0
# pos_lng_lat_prev5_exposure_ts_gap = 438.0
# pos_lng_lat_next5_exposure_ts_gap = 437.0
# pos_newsid_next3_exposure_ts_gap = 434.0
# pos_lng_lat_prev3_exposure_ts_gap = 433.0
# pos_lng_lat_next3_exposure_ts_gap = 426.0
# pos_lng_lat_prev10_exposure_ts_gap = 424.0
# cross_deviceid_netmodel_nunique = 422.0
# cross_newsid_pos_nunique_ratio_newsid_count = 421.0
# pos_lng_lat_next10_exposure_ts_gap = 418.0
# pos_netmodel_lng_lat_prev3_exposure_ts_gap = 418.0
# cross_deviceid_lng_lat_ent = 413.0
# pos_netmodel_deviceid_lng_lat_next5_exposure_ts_gap = 412.0
# pos_netmodel_lng_lat_prev10_exposure_ts_gap = 411.0
# deviceid_prev_day_ctr = 408.0
# pos_deviceid_lng_lat_prev10_exposure_ts_gap = 407.0
# pos_deviceid_lng_lat_prev3_exposure_ts_gap = 404.0
# pos_netmodel_lng_lat_next5_exposure_ts_gap = 404.0
# pos_netmodel_lng_lat_next10_exposure_ts_gap = 399.0
# pos_netmodel_deviceid_lng_lat_prev5_exposure_ts_gap = 392.0
# pos_newsid_next5_exposure_ts_gap = 385.0
# pos_netmodel_deviceid_lng_lat_prev10_exposure_ts_gap = 382.0
# pos_newsid_prev2_exposure_ts_gap = 365.0
# cross_pos_lng_lat_nunique_ratio_pos_count = 363.0
# pos_netmodel_deviceid_lng_lat_next10_exposure_ts_gap = 355.0
# pos_deviceid_lng_lat_next10_exposure_ts_gap = 341.0
# device_version_count = 336.0
# cross_deviceid_pos_count_ratio = 334.0
# cross_netmodel_lng_lat_count_ratio = 321.0
# cross_deviceid_pos_count = 315.0
# cross_lng_lat_newsid_count_ratio = 309.0
# cross_newsid_netmodel_nunique_ratio_newsid_count = 308.0
# cross_pos_deviceid_nunique = 290.0
# cross_lng_lat_netmodel_ent = 281.0
# cross_deviceid_lng_lat_nunique = 279.0
# cross_newsid_lng_lat_count_ratio = 277.0
# cross_deviceid_pos_ent = 263.0
# cross_deviceid_lng_lat_count = 258.0
# cross_newsid_lng_lat_count = 251.0
# cross_lng_lat_pos_nunique_ratio_lng_lat_count = 249.0
# pos_deviceid_prev_day_count = 241.0
# newsid_prev10_exposure_ts_gap = 238.0
# cross_newsid_lng_lat_ent = 237.0
# cross_deviceid_netmodel_nunique_ratio_deviceid_count = 225.0
# pos_deviceid_prev_day_click_count = 221.0
# cross_lng_lat_deviceid_count_ratio = 221.0
# cross_newsid_netmodel_count_ratio = 219.0
# cross_deviceid_newsid_nunique = 217.0
# cross_pos_netmodel_count_ratio = 217.0
# cross_pos_deviceid_ent = 216.0
# cross_newsid_netmodel_count = 209.0
# hour = 206.0
# cross_pos_lng_lat_count = 200.0
# cross_pos_deviceid_count_ratio = 198.0
# cross_lng_lat_netmodel_count_ratio = 192.0
# pos_newsid_next10_exposure_ts_gap = 191.0
# cross_newsid_deviceid_ent = 191.0
# deviceid_prev_day_count = 185.0
# cross_lng_lat_pos_nunique = 182.0
# pos_newsid_prev3_exposure_ts_gap = 181.0
# cross_deviceid_lng_lat_nunique_ratio_deviceid_count = 176.0
# cross_deviceid_newsid_ent = 175.0
# cross_netmodel_lng_lat_count = 164.0
# cross_newsid_pos_count = 163.0
# deviceid_prev_day_click_count = 149.0
# cross_deviceid_newsid_count = 149.0
# deviceid_count = 147.0
# newsid_count = 142.0
# pos_newsid_prev10_exposure_ts_gap = 142.0
# cross_pos_newsid_ent = 134.0
# pos_newsid_prev5_exposure_ts_gap = 133.0
# cross_lng_lat_deviceid_nunique_ratio_lng_lat_count = 132.0
# lat_count = 118.0
# cross_deviceid_lng_lat_count_ratio = 104.0
# lng_count = 99.0
# cross_newsid_deviceid_count_ratio = 99.0
# cross_lng_lat_newsid_nunique_ratio_lng_lat_count = 91.0
# cross_lng_lat_netmodel_nunique_ratio_lng_lat_count = 84.0
# app_version_count = 82.0
# cross_newsid_lng_lat_nunique = 78.0
# device_vendor_count = 73.0
# osversion_count = 68.0
# cross_newsid_deviceid_nunique = 65.0
# cross_newsid_pos_nunique = 55.0
# cross_pos_deviceid_nunique_ratio_pos_count = 52.0
# cross_deviceid_pos_nunique = 49.0
# cross_lng_lat_newsid_ent = 42.0
# cross_lng_lat_newsid_nunique = 32.0
# lng_lat_count = 21.0
# cross_pos_newsid_nunique_ratio_pos_count = 21.0
# cross_newsid_netmodel_nunique = 20.0
# cross_netmodel_deviceid_nunique = 19.0
# osversion = 17.0
# cross_pos_lng_lat_ent = 17.0
# cross_deviceid_netmodel_count_ratio = 9.0
# cross_netmodel_deviceid_ent = 7.0
# cross_pos_netmodel_nunique_ratio_pos_count = 6.0
# app_version = 4.0
# cross_lng_lat_netmodel_nunique = 4.0
# device_vendor = 3.0
# cross_pos_newsid_nunique = 2.0
# cross_lng_lat_deviceid_nunique = 2.0
# cross_netmodel_deviceid_nunique_ratio_netmodel_count = 1.0
# cross_lng_lat_deviceid_ent = 1.0
# netmodel = 0.0
# cross_pos_netmodel_nunique = 0.0
# cross_pos_lng_lat_nunique = 0.0
# cross_netmodel_newsid_nunique = 0.0
# cross_netmodel_newsid_ent = 0.0
# cross_netmodel_newsid_nunique_ratio_netmodel_count = 0.0
# cross_netmodel_pos_nunique = 0.0
# cross_netmodel_pos_ent = 0.0
# cross_netmodel_pos_nunique_ratio_netmodel_count = 0.0
# cross_netmodel_lng_lat_nunique = 0.0
# cross_netmodel_lng_lat_ent = 0.0
# cross_netmodel_lng_lat_nunique_ratio_netmodel_count = 0.0

# %%
print('=============================================== threshold search ===============================================')
# f1阈值敏感，所以对阈值做一个简单的迭代搜索。
t0 = 0.05
v = 0.002
best_t = t0
best_f1 = 0
for step in range(201):
    curr_t = t0 + step * v
    y = [1 if x >= curr_t else 0 for x in val_pred]
    curr_f1 = f1_score(val_y, y)
    if curr_f1 > best_f1:
        best_t = curr_t
        best_f1 = curr_f1
        print('step: {}   best threshold: {}   best f1: {}'.format(step, best_t, best_f1))
print('search finish.')

val_pred = [1 if x >= best_t else 0 for x in val_pred]
print('\nbest auc:', best_auc)
print('best f1:', f1_score(val_y, val_pred))
print('validate mean:', np.mean(val_pred))
print('runtime:', time.time() - t)
# Out:
# =============================================== threshold search ===============================================
# step: 0   best threshold: 0.05   best f1: 0.6997430713166896
# step: 1   best threshold: 0.052000000000000005   best f1: 0.7023112620488454
# step: 2   best threshold: 0.054000000000000006   best f1: 0.7047099608620907
# step: 3   best threshold: 0.056   best f1: 0.7068569901490088
# step: 4   best threshold: 0.058   best f1: 0.7087415502199624
# step: 5   best threshold: 0.060000000000000005   best f1: 0.710591678219499
# step: 6   best threshold: 0.062   best f1: 0.7122296888635893
# step: 7   best threshold: 0.064   best f1: 0.7137043205994118
# step: 8   best threshold: 0.066   best f1: 0.7150138315006197
# step: 9   best threshold: 0.068   best f1: 0.7163322620434747
# step: 10   best threshold: 0.07   best f1: 0.7174975604048065
# step: 11   best threshold: 0.07200000000000001   best f1: 0.7183878005054323
# step: 12   best threshold: 0.07400000000000001   best f1: 0.7192221056495739
# step: 13   best threshold: 0.07600000000000001   best f1: 0.7199101832375536
# step: 14   best threshold: 0.078   best f1: 0.7207723675005574
# step: 15   best threshold: 0.08   best f1: 0.721433610712113
# step: 16   best threshold: 0.082   best f1: 0.721978125641609
# step: 17   best threshold: 0.084   best f1: 0.7224561407422362
# step: 18   best threshold: 0.08600000000000001   best f1: 0.7228623979072026
# step: 19   best threshold: 0.088   best f1: 0.7230930342544422
# step: 20   best threshold: 0.09   best f1: 0.7233805710381246
# step: 21   best threshold: 0.092   best f1: 0.7236292721954146
# step: 22   best threshold: 0.094   best f1: 0.7237933695250184
# step: 23   best threshold: 0.096   best f1: 0.7238270376366029
# search finish.
#
# best auc: 0.9724794667703146
# best f1: 0.7238270376366029
# validate mean: 0.11478410523813265
# runtime: 4497.899462223053

# %%
print('=============================================== sub save ===============================================')
sub.to_csv('sub_prob_{}_{}_{}.csv'.format(best_auc, best_f1, sub['target'].mean()), index=False)
sub['target'] = sub['target'].apply(lambda x: 1 if x >= best_t else 0)
sub.to_csv('sub_{}_{}_{}.csv'.format(best_auc, best_f1, sub['target'].mean()), index=False)
print('runtime:', time.time() - t)
print('finish.')
print('========================================================================================================')
# Out:
# =============================================== sub save ===============================================
# runtime: 4523.013119459152
# finish.
# ========================================================================================================
