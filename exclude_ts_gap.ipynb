# %%
# -*- coding:utf-8 -*-
"""

Author:
    ruiyan zry,15617240@qq.com

"""

import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from lightgbm.sklearn import LGBMClassifier
from sklearn.metrics import roc_auc_score, f1_score
from scipy.stats import entropy
from gensim.models import Word2Vec
import time
import gc

pd.set_option('display.max_columns', None)

from core.utils import timeit, reduce_mem

# %%
##################################################################################################################

# 1、有些说明在前一次开源已经说了，在这里就不说了；
# 2、主要包含四组特征：
# （1）历史信息，即前一天的点击量、曝光量、点击率；
# （2）前x次曝光、后x次曝光到当前的时间差。后x次到当前曝光的时间差是穿越特征，并且是最强的特征；
# （3）二阶交叉特征；
# （4）embedding。
# 3、本来想一开到底的，但是得知15号之后就不让开源了，所以这应该是最后一次了，没机会为大家打开另外两张表了，大家自行发挥吧；
# 4、希望大家都能拿第一名。

##################################################################################################################


path = "/media/ryan/F/deep-learning-data/turing/vedio-predict/"
path_sub = path + 'sub/'
path_npy = path + 'npy/'
path_data = path + 'raw/'
path_model = path + 'model/'
path_result = path + 'result/'
path_pickle = path + 'pickle/'
path_profile = path + 'profile/'

debug_small = False
sub_sample = False
if debug_small:
    train_df = pd.read_pickle(path_pickle + 'train_small.pickle')
    test_df = pd.read_pickle(path_pickle + 'test_small.pickle')
    # app = pd.read_pickle(path_pickle + 'app_small.pickle')
    # user = pd.read_pickle(path_pickle + 'user_small.pickle')

else:
    train_df = pd.read_pickle(path_pickle + 'train.pickle')
    test_df = pd.read_pickle(path_pickle + 'test.pickle')


    # app = pd.read_pickle(path_pickle + 'app.pickle')
    # user = pd.read_pickle(path_pickle + 'user.pickle')

    if sub_sample:
        train_df = train_df[train_df.deviceid.str[-1] == '1']
        test_df = test_df[test_df.deviceid.str[-1] == '1']

# %%
print('=============================================== read train ===============================================')
t = time.time()
# train_df = pd.read_csv('dataset/train.csv')
train_df['date'] = pd.to_datetime(
    train_df['ts'].apply(lambda x: time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(x / 1000)))
)
train_df['day'] = train_df['date'].dt.day

# 训练集中，day=7的个数为11个，day=8的为3,674,871。 day9，10也是解决40w
# day=7占比不到1/百万，属于异常情况，去掉合理？ 线上的表现又会如何，为啥不是直接删除，这样有点过了
# 这里为啥只是改了day，不去直接改ts和timestamp呢？
train_df.loc[train_df['day'] == 7, 'day'] = 8
train_df['hour'] = train_df['date'].dt.hour
train_df['minute'] = train_df['date'].dt.minute
train_num = train_df.shape[0]
labels = train_df['target'].values
print('runtime:', time.time() - t)
# Out:
# =============================================== read train ===============================================
# runtime: 22.409448385238647

# %%
print('=============================================== click data ===============================================')
click_df = train_df[train_df['target'] == 1].sort_values('timestamp').reset_index(drop=True)
click_df['exposure_click_gap'] = click_df['timestamp'] - click_df['ts']
click_df = click_df[click_df['exposure_click_gap'] >= 0].reset_index(drop=True)
click_df['date'] = pd.to_datetime(
    click_df['timestamp'].apply(lambda x: time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(x / 1000)))
)
click_df['day'] = click_df['date'].dt.day
# 同上对day==7的修改
click_df.loc[click_df['day'] == 7, 'day'] = 8

del train_df['target'], train_df['timestamp']

# 这里为啥要把click_df的这些字段删除呢？
for f in ['date', 'exposure_click_gap', 'timestamp', 'ts', 'target', 'hour', 'minute']:
    del click_df[f]
print('runtime:', time.time() - t)
# Out:
# =============================================== click data ===============================================
# runtime: 34.62693381309509

# %%
print('=============================================== read test ===============================================')
test_df['date'] = pd.to_datetime(
    test_df['ts'].apply(lambda x: time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(x / 1000)))
)
test_df['day'] = test_df['date'].dt.day

# 测试集中，day=10的个数为32个，day=11的为3,653,560占比 1/十万，属于异常情况，去掉合理
test_df.loc[test_df['day'] == 10, 'day'] = 11
test_df['hour'] = test_df['date'].dt.hour
test_df['minute'] = test_df['date'].dt.minute
df = pd.concat([train_df, test_df], axis=0, ignore_index=False)
del train_df, test_df, df['date']
gc.collect()
print('runtime:', time.time() - t)
# Out:
# =============================================== read test ===============================================
# runtime: 59.27189826965332

# %%
print('============================================= category encoding =============================================')
df['lng_lat'] = df['lng'].astype('str') + '_' + df['lat'].astype('str')
del df['guid']
click_df['lng_lat'] = click_df['lng'].astype('str') + '_' + click_df['lat'].astype('str')
sort_df = df.sort_values('ts').reset_index(drop=True)
cate_cols = [
    'deviceid', 'newsid', 'pos', 'app_version', 'device_vendor',
    'netmodel', 'osversion', 'device_version', 'lng', 'lat', 'lng_lat'
]
for f in cate_cols:
    print(f)
    map_dict = dict(zip(df[f].unique(), range(df[f].nunique())))
    df[f] = df[f].map(map_dict).fillna(-1).astype('int32')
    click_df[f] = click_df[f].map(map_dict).fillna(-1).astype('int32')
    sort_df[f] = sort_df[f].map(map_dict).fillna(-1).astype('int32')
    df[f + '_count'] = df[f].map(df[f].value_counts())
df = reduce_mem(df)
click_df = reduce_mem(click_df)
sort_df = reduce_mem(sort_df)
print('runtime:', time.time() - t)
# Out:
# ============================================= category encoding =============================================
# deviceid
# newsid
# pos
# app_version
# device_vendor
# netmodel
# osversion
# device_version
# lng
# lat
# lng_lat
# 2580.12 Mb, 1390.40 Mb (46.11 %)
# 77.91 Mb, 46.97 Mb (39.71 %)
# 1204.05 Mb, 673.70 Mb (44.05 %)
# runtime: 185.4272334575653

# %%
print('============================================= feat engineer =============================================')

print('*************************** history stats ***************************')
for f in [
    ['deviceid'],
    ['pos', 'deviceid'],
    # ...
]:
    print('------------------ {} ------------------'.format('_'.join(f)))

    # 对前一天的点击次数进行统计
    tmp = click_df[f + ['day', 'id']].groupby(f + ['day'], as_index=False)['id'].agg(
        {'_'.join(f) + '_prev_day_click_count': 'count'})
    tmp['day'] += 1
    df = df.merge(tmp, on=f + ['day'], how='left')
    df['_'.join(f) + '_prev_day_click_count'] = df['_'.join(f) + '_prev_day_click_count'].fillna(0)
    df.loc[df['day'] == 8, '_'.join(f) + '_prev_day_click_count'] = None

    # 对前一天的曝光量进行统计
    tmp = df[f + ['day', 'id']].groupby(f + ['day'], as_index=False)['id'].agg(
        {'_'.join(f) + '_prev_day_count': 'count'})
    tmp['day'] += 1
    df = df.merge(tmp, on=f + ['day'], how='left')
    df['_'.join(f) + '_prev_day_count'] = df['_'.join(f) + '_prev_day_count'].fillna(0)
    df.loc[df['day'] == 8, '_'.join(f) + '_prev_day_count'] = None

    # 计算前一天的点击率
    df['_'.join(f) + '_prev_day_ctr'] = df['_'.join(f) + '_prev_day_click_count'] / (
            df['_'.join(f) + '_prev_day_count'] + df['_'.join(f) + '_prev_day_count'].mean())

    del tmp
    print('runtime:', time.time() - t)
del click_df
df = reduce_mem(df)
# Out:
# ============================================= feat engineer =============================================
# *************************** history stats ***************************
# ------------------ deviceid ------------------
# runtime: 197.60648822784424
# ------------------ pos_deviceid ------------------
# runtime: 212.74193501472473
# 2078.43 Mb, 1562.40 Mb (24.83 %)

# %%
print('*************************** cross feat (second order) ***************************')
# 二阶交叉特征，可以继续做更高阶的交叉。
# cross_cols = ['deviceid', 'newsid', 'pos', 'netmodel', 'lng_lat']
# for f in cross_cols:
#     for col in cross_cols:
#         if col == f:
#             continue
#         print('------------------ {} {} ------------------'.format(f, col))
#         df = df.merge(df[[f, col]].groupby(f, as_index=False)[col].agg({
#             'cross_{}_{}_nunique'.format(f, col): 'nunique',
#             'cross_{}_{}_ent'.format(f, col): lambda x: entropy(x.value_counts() / x.shape[0])  # 熵
#         }), on=f, how='left')
#         if 'cross_{}_{}_count'.format(f, col) not in df.columns.values and 'cross_{}_{}_count'.format(col,
#                                                                                                       f) not in df.columns.values:
#             df = df.merge(df[[f, col, 'id']].groupby([f, col], as_index=False)['id'].agg({
#                 'cross_{}_{}_count'.format(f, col): 'count'  # 共现次数
#             }), on=[f, col], how='left')
#         if 'cross_{}_{}_count_ratio'.format(col, f) not in df.columns.values:
#             df['cross_{}_{}_count_ratio'.format(col, f)] = df['cross_{}_{}_count'.format(f, col)] / df[
#                 f + '_count']  # 比例偏好
#         if 'cross_{}_{}_count_ratio'.format(f, col) not in df.columns.values:
#             df['cross_{}_{}_count_ratio'.format(f, col)] = df['cross_{}_{}_count'.format(f, col)] / df[
#                 col + '_count']  # 比例偏好
#         df['cross_{}_{}_nunique_ratio_{}_count'.format(f, col, f)] = df['cross_{}_{}_nunique'.format(f, col)] / df[
#             f + '_count']
#         print('runtime:', time.time() - t)
#     df = reduce_mem(df)
del df['id']
gc.collect()

# %%
print('*************************** embedding ***************************')


# 之前有个朋友给embedding做了一个我认为非常形象的比喻：
# 在非诚勿扰上面，如果你想了解一个女嘉宾，那么你可以看看她都中意过哪些男嘉宾；
# 反过来也一样，如果你想认识一个男嘉宾，那么你也可以看看他都选过哪些女嘉宾。


def emb(df, f1, f2):
    emb_size = 8
    print('====================================== {} {} ======================================'.format(f1, f2))
    tmp = df.groupby(f1, as_index=False)[f2].agg({'{}_{}_list'.format(f1, f2): list})
    sentences = tmp['{}_{}_list'.format(f1, f2)].values.tolist()
    del tmp['{}_{}_list'.format(f1, f2)]
    for i in range(len(sentences)):
        sentences[i] = [str(x) for x in sentences[i]]
    model = Word2Vec(sentences, size=emb_size, window=5, min_count=5, sg=0, hs=1, seed=2019)
    emb_matrix = []
    for seq in sentences:
        vec = []
        for w in seq:
            if w in model:
                vec.append(model[w])
        if len(vec) > 0:
            emb_matrix.append(np.mean(vec, axis=0))
        else:
            emb_matrix.append([0] * emb_size)

    # 为了支持数组多维处理，需要先做一个变换
    emb_matrix = np.array(emb_matrix)

    for i in range(emb_size):
        tmp['{}_{}_emb_{}'.format(f1, f2, i)] = emb_matrix[:, i]
    del model, emb_matrix, sentences
    tmp = reduce_mem(tmp)
    print('runtime:', time.time() - t)
    return tmp


emb_cols = [
    ['deviceid', 'newsid'],
    ['deviceid', 'lng_lat'],
    ['newsid', 'lng_lat'],
    # ...
]
for f1, f2 in emb_cols:
    df = df.merge(emb(sort_df, f1, f2), on=f1, how='left')
    df = df.merge(emb(sort_df, f2, f1), on=f2, how='left')
del sort_df
gc.collect()
# Out:
# *************************** embedding ***************************
# ====================================== deviceid newsid ======================================
# INFO:MainThread:gensim.models.word2vec:collecting all words and their counts
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #10000, processed 1903504 words, keeping 448947 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #20000, processed 3645506 words, keeping 652836 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #30000, processed 5610194 words, keeping 821406 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #40000, processed 7484615 words, keeping 947066 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #50000, processed 9175854 words, keeping 1050483 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #60000, processed 11009015 words, keeping 1147302 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #70000, processed 12879752 words, keeping 1244174 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #80000, processed 14183387 words, keeping 1293163 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #90000, processed 14386101 words, keeping 1297658 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #100000, processed 14517353 words, keeping 1300696 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #110000, processed 14841574 words, keeping 1313687 word types
# INFO:MainThread:gensim.models.word2vec:collected 1319604 word types from a corpus of 15030273 raw words and 114584 sentences
# INFO:MainThread:gensim.models.word2vec:Loading a fresh vocabulary
# INFO:MainThread:gensim.models.word2vec:effective_min_count=5 retains 362132 unique words (27% of original 1319604, drops 957472)
# INFO:MainThread:gensim.models.word2vec:effective_min_count=5 leaves 13421969 word corpus (89% of original 15030273, drops 1608304)
# INFO:MainThread:gensim.models.word2vec:deleting the raw counts dictionary of 1319604 items
# INFO:MainThread:gensim.models.word2vec:sample=0.001 downsamples 0 most-common words
# INFO:MainThread:gensim.models.word2vec:downsampling leaves estimated 13421969 word corpus (100.0% of prior 13421969)
# INFO:MainThread:gensim.models.word2vec:constructing a huffman tree from 362132 words
# INFO:MainThread:gensim.models.word2vec:built huffman tree with maximum node depth 21
# INFO:MainThread:gensim.models.base_any2vec:estimated required memory for 362132 words and 8 dimensions: 288257072 bytes
# INFO:MainThread:gensim.models.word2vec:resetting layer weights
# INFO:MainThread:gensim.models.base_any2vec:training model with 3 workers on 362132 vocabulary and 8 features, using sg=0 hs=1 sample=0.001 negative=5 window=5
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 3.05% examples, 518452 words/s, in_qsize 6, out_qsize 1
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 5.64% examples, 516166 words/s, in_qsize 6, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 8.32% examples, 516208 words/s, in_qsize 6, out_qsize 1
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 10.90% examples, 508866 words/s, in_qsize 6, out_qsize 1
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 13.61% examples, 497936 words/s, in_qsize 5, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 16.28% examples, 494068 words/s, in_qsize 5, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 19.12% examples, 493117 words/s, in_qsize 6, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 21.74% examples, 492567 words/s, in_qsize 6, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 24.48% examples, 496989 words/s, in_qsize 5, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 27.06% examples, 497522 words/s, in_qsize 6, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 29.82% examples, 498149 words/s, in_qsize 5, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 32.77% examples, 500372 words/s, in_qsize 5, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 35.83% examples, 499853 words/s, in_qsize 4, out_qsize 1
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 39.00% examples, 499740 words/s, in_qsize 5, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 41.62% examples, 498938 words/s, in_qsize 6, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 44.39% examples, 497711 words/s, in_qsize 5, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 47.27% examples, 498764 words/s, in_qsize 5, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 49.89% examples, 497636 words/s, in_qsize 5, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 52.70% examples, 497104 words/s, in_qsize 5, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 55.35% examples, 497410 words/s, in_qsize 5, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 58.03% examples, 497420 words/s, in_qsize 5, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 60.62% examples, 497039 words/s, in_qsize 6, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 63.28% examples, 495071 words/s, in_qsize 4, out_qsize 1
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 66.60% examples, 496666 words/s, in_qsize 6, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 90.32% examples, 495897 words/s, in_qsize 4, out_qsize 1
# INFO:MainThread:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:MainThread:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:MainThread:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:MainThread:gensim.models.base_any2vec:EPOCH - 1 : training on 15030273 raw words (13004444 effective words) took 26.2s, 497069 effective words/s
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 3.14% examples, 557981 words/s, in_qsize 5, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 5.82% examples, 541800 words/s, in_qsize 5, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 8.53% examples, 528152 words/s, in_qsize 5, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 11.21% examples, 519592 words/s, in_qsize 6, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 13.99% examples, 510116 words/s, in_qsize 5, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 16.67% examples, 503694 words/s, in_qsize 6, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 19.29% examples, 498527 words/s, in_qsize 3, out_qsize 2
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 21.74% examples, 492311 words/s, in_qsize 6, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 24.35% examples, 493298 words/s, in_qsize 5, out_qsize 0
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at
word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #750000, processed 13833991 words, keeping 114559 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #760000, processed 13857851 words, keeping 114561 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #770000, processed 13883058 words, keeping 114563 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #780000, processed 13907976 words, keeping 114563 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #790000, processed 13931954 words, keeping 114564 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #800000, processed 13954647 words, keeping 114564 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #810000, processed 13978989 words, keeping 114566 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #820000, processed 14003459 words, keeping 114568 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #830000, processed 14024931 words, keeping 114568 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #840000, processed 14050716 words, keeping 114568 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #850000, processed 14071598 words, keeping 114568 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #860000, processed 14092683 words, keeping 114569 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #870000, processed 14114168 words, keeping 114569 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #880000, processed 14134385 words, keeping 114571 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #890000, processed 14154834 words, keeping 114571 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #900000, processed 14174593 words, keeping 114571 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #910000, processed 14193994 words, keeping 114571 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #920000, processed 14213958 words, keeping 114572 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #930000, processed 14232716 words, keeping 114572 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #940000, processed 14251840 words, keeping 114574 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #950000, processed 14270526 words, keeping 114574 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #960000, processed 14288966 words, keeping 114575 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #970000, processed 14309745 words, keeping 114576 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #980000, processed 14326998 words, keeping 114576 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #990000, processed 14345260 words, keeping 114576 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1000000, processed 14362366 words, keeping 114576 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1010000, processed 14379933 words, keeping 114576 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1020000, processed 14399006 words, keeping 114576 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1030000, processed 14415240 words, keeping 114576 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1040000, processed 14433051 words, keeping 114576 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1050000, processed 14449122 words, keeping 114576 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1060000, processed 14465373 words, keeping 114577 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1070000, processed 14481200 words, keeping 114577 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1080000, processed 14498649 words, keeping 114577 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1090000, processed 14514405 words, keeping 114577 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1100000, processed 14530082 words, keeping 114577 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1110000, processed 14544886 words, keeping 114577 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1120000, processed 14561121 words, keeping 114578 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1130000, processed 14576128 words, keeping 114579 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1140000, processed 14591433 words, keeping 114579 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1150000, processed 14606784 words, keeping 114579 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1160000, processed 14744925 words, keeping 114579 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1170000, processed 14807326 words, keeping 114579 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1180000, processed 14848466 words, keeping 114580 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1190000, processed 14869933 words, keeping 114580 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1200000, processed 14887651 words, keeping 114580 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1210000, processed 14902035 words, keeping 114581 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1220000, processed 14915574 words, keeping 114582 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1230000, processed 14928338 words, keeping 114583 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1240000, processed 14940724 words, keeping 114583 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1250000, processed 14952921 words, keeping 114583 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1260000, processed 14964556 words, keeping 114583 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1270000, processed 14976009 words, keeping 114583 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1280000, processed 14987413 words, keeping 114584 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1290000, processed 14998437 words, keeping 114584 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1300000, processed 15009280 words, keeping 114584 word types
# INFO:MainThread:gensim.models.word2vec:PROGRESS: at sentence #1310000, processed 15020149 words, keeping 114584 word types
# INFO:MainThread:gensim.models.word2vec:collected 114584 word types from a corpus of 15030273 raw words and 1319604 sentences
# INFO:MainThread:gensim.models.word2vec:Loading a fresh vocabulary
# INFO:MainThread:gensim.models.word2vec:effective_min_count=5 retains 107489 unique words (93% of original 114584, drops 7095)
# INFO:MainThread:gensim.models.word2vec:effective_min_count=5 leaves 15005254 word corpus (99% of original 15030273, drops 25019)
# INFO:MainThread:gensim.models.word2vec:deleting the raw counts dictionary of 114584 items
# INFO:MainThread:gensim.models.word2vec:sample=0.001 downsamples 4 most-common words
# INFO:MainThread:gensim.models.word2vec:downsampling leaves estimated 14929795 word corpus (99.5% of prior 15005254)
# INFO:MainThread:gensim.models.word2vec:constructing a huffman tree from 107489 words
# INFO:MainThread:gensim.models.word2vec:built huffman tree with maximum node depth 22
# INFO:MainThread:gensim.models.base_any2vec:estimated required memory for 107489 words and 8 dimensions: 85561244 bytes
# INFO:MainThread:gensim.models.word2vec:resetting layer weights
# INFO:MainThread:gensim.models.base_any2vec:training model with 3 workers on 107489 vocabulary and 8 features, using sg=0 hs=1 sample=0.001 negative=5 window=5
# INFO:MainThread:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at
gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:MainThread:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:MainThread:gensim.models.base_any2vec:EPOCH - 5 : training on 15030273 raw words (11206052 effective words) took 24.0s, 467844 effective words/s
# INFO:MainThread:gensim.models.base_any2vec:training on a 75151365 raw words (56030260 effective words) took 120.3s, 465869 effective words/s
# 35.64 Mb, 12.48 Mb (65.00 %)
# runtime: 2255.636177778244
# 0

# %%
print('======================================== prepare train & valid  =============================================')
train_df = df[:train_num].reset_index(drop=True)
test_df = df[train_num:].reset_index(drop=True)
del df
gc.collect()

train_idx = train_df[train_df['day'] < 10].index.tolist()
val_idx = train_df[train_df['day'] == 10].index.tolist()

train_x = train_df.iloc[train_idx].reset_index(drop=True)
train_y = labels[train_idx]
val_x = train_df.iloc[val_idx].reset_index(drop=True)
val_y = labels[val_idx]

del train_x['day'], val_x['day'], train_df['day'], test_df['day']
gc.collect()
print('runtime:', time.time() - t)
print('========================================================================================================')
# Out:
# ======================================== prepare train & valid  =============================================
# runtime: 2270.176098585129
# ========================================================================================================

# %%
# train_df.to_pickle(path_pickle + "81_all_final_train.pickle")
# test_df.to_pickle(path_pickle + "81_all_final_test.pickle")

# %%
print('=============================================== training validate ===============================================')
fea_imp_list = []
clf = LGBMClassifier(
    learning_rate=0.01,
    n_estimators=5000,
    num_leaves=255,
    subsample=0.9,
    colsample_bytree=0.8,
    random_state=2019,
    metric=None
)

print('************** training **************')
clf.fit(
    train_x, train_y,
    eval_set=[(val_x, val_y)],
    eval_metric='auc',
    categorical_feature=cate_cols,
    early_stopping_rounds=200,
    verbose=50
)
print('runtime:', time.time() - t)

print('************** validate predict **************')
best_rounds = clf.best_iteration_
best_auc = clf.best_score_['valid_0']['auc']
val_pred = clf.predict_proba(val_x)[:, 1]
fea_imp_list.append(clf.feature_importances_)
print('runtime:', time.time() - t)
# Out:
# =============================================== training validate ===============================================
# ************** training **************
# Training until validation scores don't improve for 200 rounds
# [50]	valid_0's auc: 0.900812
# [100]	valid_0's auc: 0.904232
# [150]	valid_0's auc: 0.905775
# [200]	valid_0's auc: 0.906636
# [250]	valid_0's auc: 0.907599
# [300]	valid_0's auc: 0.9082
# [350]	valid_0's auc: 0.908885
# [400]	valid_0's auc: 0.909591
# [450]	valid_0's auc: 0.909915
# [500]	valid_0's auc: 0.910137
# [550]	valid_0's auc: 0.910315
# [600]	valid_0's auc: 0.910425
# [650]	valid_0's auc: 0.91048
# [700]	valid_0's auc: 0.910514
# [750]	valid_0's auc: 0.910545
# [800]	valid_0's auc: 0.910553
# [850]	valid_0's auc: 0.910536
# [900]	valid_0's auc: 0.910497
# [950]	valid_0's auc: 0.910465
# Early stopping, best iteration is:
# [797]	valid_0's auc: 0.910567
# runtime: 7443.5404760837555
# ************** validate predict **************
# runtime: 9096.90061211586

# %%
print('=============================================== training predict ===============================================')
clf = LGBMClassifier(
    learning_rate=0.01,
    n_estimators=best_rounds,
    num_leaves=255,
    subsample=0.9,
    colsample_bytree=0.8,
    random_state=2019
)

print('************** training **************')
clf.fit(
    train_df, labels,
    eval_set=[(train_df, labels)],
    categorical_feature=cate_cols,
    verbose=50
)
print('runtime:', time.time() - t)
# Out:
# =============================================== training predict ===============================================
# ************** training **************
# [50]	training's binary_logloss: 0.250592
# [100]	training's binary_logloss: 0.217604
# [150]	training's binary_logloss: 0.20104
# [200]	training's binary_logloss: 0.191788
# [250]	training's binary_logloss: 0.186001
# [300]	training's binary_logloss: 0.182126
# [350]	training's binary_logloss: 0.17927
# [400]	training's binary_logloss: 0.1769
# [450]	training's binary_logloss: 0.174873
# [500]	training's binary_logloss: 0.173101
# [550]	training's binary_logloss: 0.171569
# [600]	training's binary_logloss: 0.170175
# [650]	training's binary_logloss: 0.168934
# [700]	training's binary_logloss: 0.167762
# [750]	training's binary_logloss: 0.166652
# runtime: 12322.643056631088

# %%
print('************** test predict **************')
sub = pd.read_csv(path_data + 'sample.csv')
sub['target'] = clf.predict_proba(test_df)[:, 1]
# tmp_df = clf.predict_proba(test_df)[:, 1]
fea_imp_list.append(clf.feature_importances_)
print('runtime:', time.time() - t)
# Out:
# ************** test predict **************
# runtime: 13446.176961421967

# %%
print('=============================================== feat importances ===============================================')
# 特征重要性可以好好看看
fea_imp_dict = dict(zip(train_df.columns.values, np.mean(fea_imp_list, axis=0)))
fea_imp_item = sorted(fea_imp_dict.items(), key=lambda x: x[1], reverse=True)
for f, imp in fea_imp_item:
    print('{} = {}'.format(f, imp))
# Out:
# =============================================== feat importances ===============================================
# deviceid = 73627.0
# newsid = 31846.5
# device_version = 28110.5
# lat = 14211.5
# lng = 13346.0
# lng_lat = 7782.0
# deviceid_count = 2736.5
# lng_lat_count = 2446.5
# deviceid_newsid_emb_6 = 1794.5
# deviceid_newsid_emb_5 = 1572.0
# netmodel_count = 1354.5
# deviceid_newsid_emb_0 = 1344.5
# pos = 1298.5
# lng_lat_newsid_emb_1 = 1193.0
# pos_count = 1122.0
# deviceid_newsid_emb_2 = 1081.0
# deviceid_prev_day_ctr = 873.5
# pos_deviceid_prev_day_ctr = 805.0
# deviceid_newsid_emb_4 = 742.0
# pos_deviceid_prev_day_count = 735.0
# newsid_count = 671.0
# hour = 668.0
# deviceid_newsid_emb_1 = 659.0
# deviceid_newsid_emb_7 = 652.0
# deviceid_prev_day_count = 634.5
# lng_lat_newsid_emb_7 = 619.5
# deviceid_newsid_emb_3 = 556.5
# lng_count = 549.0
# lng_lat_newsid_emb_0 = 516.0
# ts = 507.0
# newsid_deviceid_emb_6 = 456.0
# newsid_lng_lat_emb_6 = 442.0
# lat_count = 419.0
# newsid_deviceid_emb_3 = 382.0
# newsid_lng_lat_emb_1 = 378.5
# lng_lat_newsid_emb_6 = 321.5
# netmodel = 313.5
# lng_lat_newsid_emb_4 = 309.0
# newsid_deviceid_emb_0 = 306.0
# minute = 305.0
# app_version = 287.5
# newsid_deviceid_emb_5 = 279.0
# newsid_deviceid_emb_7 = 274.5
# newsid_deviceid_emb_4 = 250.0
# newsid_lng_lat_emb_5 = 248.0
# newsid_deviceid_emb_1 = 243.0
# newsid_deviceid_emb_2 = 210.0
# device_vendor = 208.5
# deviceid_prev_day_click_count = 171.5
# deviceid_lng_lat_emb_1 = 138.5
# pos_deviceid_prev_day_click_count = 123.0
# lng_lat_newsid_emb_3 = 118.5
# lng_lat_newsid_emb_2 = 115.5
# lng_lat_newsid_emb_5 = 112.5
# deviceid_lng_lat_emb_6 = 111.0
# deviceid_lng_lat_emb_7 = 110.0
# deviceid_lng_lat_emb_4 = 105.0
# newsid_lng_lat_emb_3 = 105.0
# deviceid_lng_lat_emb_3 = 104.0
# deviceid_lng_lat_emb_0 = 102.5
# deviceid_lng_lat_emb_5 = 101.5
# lng_lat_deviceid_emb_7 = 101.5
# deviceid_lng_lat_emb_2 = 100.0
# lng_lat_deviceid_emb_6 = 94.0
# newsid_lng_lat_emb_7 = 90.0
# lng_lat_deviceid_emb_4 = 88.0
# lng_lat_deviceid_emb_0 = 86.0
# device_version_count = 85.5
# newsid_lng_lat_emb_0 = 80.0
# newsid_lng_lat_emb_2 = 72.5
# lng_lat_deviceid_emb_1 = 70.5
# lng_lat_deviceid_emb_2 = 69.0
# newsid_lng_lat_emb_4 = 67.5
# lng_lat_deviceid_emb_5 = 57.0
# lng_lat_deviceid_emb_3 = 51.5
# device_vendor_count = 40.0
# osversion = 32.0
# app_version_count = 25.5
# osversion_count = 21.5

# %%
print('=============================================== threshold search ===============================================')
# f1阈值敏感，所以对阈值做一个简单的迭代搜索。
t0 = 0.05
v = 0.002
best_t = t0
best_f1 = 0
for step in range(201):
    curr_t = t0 + step * v
    y = [1 if x >= curr_t else 0 for x in val_pred]
    curr_f1 = f1_score(val_y, y)
    if curr_f1 > best_f1:
        best_t = curr_t
        best_f1 = curr_f1
        print('step: {}   best threshold: {}   best f1: {}'.format(step, best_t, best_f1))
print('search finish.')

val_pred = [1 if x >= best_t else 0 for x in val_pred]
print('\nbest auc:', best_auc)
print('best f1:', f1_score(val_y, val_pred))
print('validate mean:', np.mean(val_pred))
print('runtime:', time.time() - t)
# Out:
# =============================================== threshold search ===============================================
# step: 0   best threshold: 0.05   best f1: 0.4429750057829941
# step: 1   best threshold: 0.052000000000000005   best f1: 0.44584488302145736
# step: 2   best threshold: 0.054000000000000006   best f1: 0.4485423035291598
# step: 3   best threshold: 0.056   best f1: 0.45125752296864097
# step: 4   best threshold: 0.058   best f1: 0.45392608805128903
# step: 5   best threshold: 0.060000000000000005   best f1: 0.45646384513097654
# step: 6   best threshold: 0.062   best f1: 0.458943098941178
# step: 7   best threshold: 0.064   best f1: 0.4613622522809429
# step: 8   best threshold: 0.066   best f1: 0.46378214076022384
# step: 9   best threshold: 0.068   best f1: 0.46629928417225314
# step: 10   best threshold: 0.07   best f1: 0.46879860699202425
# step: 11   best threshold: 0.07200000000000001   best f1: 0.47121908724499845
# step: 12   best threshold: 0.07400000000000001   best f1: 0.4735719134904471
# step: 13   best threshold: 0.07600000000000001   best f1: 0.4759132629855955
# step: 14   best threshold: 0.078   best f1: 0.4781175111122784
# step: 15   best threshold: 0.08   best f1: 0.480364686539613
# step: 16   best threshold: 0.082   best f1: 0.4826224217997312
# step: 17   best threshold: 0.084   best f1: 0.48491925806377917
# step: 18   best threshold: 0.08600000000000001   best f1: 0.48710494245091396
# step: 19   best threshold: 0.088   best f1: 0.4893929253421587
# step: 20   best threshold: 0.09   best f1: 0.49146552186302783
# step: 21   best threshold: 0.092   best f1: 0.49361147670257344
# step: 22   best threshold: 0.094   best f1: 0.49571776888784735
# step: 23   best threshold: 0.096   best f1: 0.4976416800650144
# step: 24   best threshold: 0.098   best f1: 0.499665056438167
# step: 25   best threshold: 0.1   best f1: 0.5016493514450883
# step: 26   best threshold: 0.10200000000000001   best f1: 0.5035837742200717
# step: 27   best threshold: 0.10400000000000001   best f1: 0.5055121148039964
# step: 28   best threshold: 0.10600000000000001   best f1: 0.5074925234807444
# step: 29   best threshold: 0.10800000000000001   best f1: 0.5093761169019119
# step: 30   best threshold: 0.11   best f1: 0.511175964855104
# step: 31   best threshold: 0.112   best f1: 0.5129218454010465
# step: 32   best threshold: 0.114   best f1: 0.51477002608695
# step: 33   best threshold: 0.116   best f1: 0.5165895279380603
# step: 34   best threshold: 0.11800000000000001   best f1: 0.5184356678868765
# step: 35   best threshold: 0.12000000000000001   best f1: 0.5201589330479672
# step: 36   best threshold: 0.12200000000000001   best f1: 0.521789428947114
# step: 37   best threshold: 0.124   best f1: 0.5235246928783921
# step: 38   best threshold: 0.126   best f1: 0.5250936329588015
# step: 39   best threshold: 0.128   best f1: 0.5265956323846892
# step: 40   best threshold: 0.13   best f1: 0.5281634400074273
# step: 41   best threshold: 0.132   best f1: 0.5296309873406496
# step: 42   best threshold: 0.134   best f1: 0.5309376881636503
# step: 43   best threshold: 0.136   best f1: 0.5322592792599347
# step: 44   best threshold: 0.138   best f1: 0.533569485450537
# step: 45   best threshold: 0.14   best f1: 0.5348774828989838
# step: 46   best threshold: 0.14200000000000002   best f1: 0.5361607248362183
# step: 47   best threshold: 0.14400000000000002   best f1: 0.5374558799064781
# step: 48   best threshold: 0.14600000000000002   best f1: 0.5386530172680164
# step: 49   best threshold: 0.14800000000000002   best f1: 0.5398519421717966
# step: 50   best threshold: 0.15000000000000002   best f1: 0.5408850907498215
# step: 51   best threshold: 0.15200000000000002   best f1: 0.5419533245620203
# step: 52   best threshold: 0.15400000000000003   best f1: 0.5430677863003879
# step: 53   best threshold: 0.156   best f1: 0.5440987800494745
# step: 54   best threshold: 0.158   best f1: 0.5450436015500884
# step: 55   best threshold: 0.16   best f1: 0.5461154347001342
# step: 56   best threshold: 0.162   best f1: 0.5470417054147744
# step: 57   best threshold: 0.164   best f1: 0.5479373099608963
# step: 58   best threshold: 0.166   best f1: 0.5488449748952814
# step: 59   best threshold: 0.168   best f1: 0.5497422604084462
# step: 60   best threshold: 0.16999999999999998   best f1: 0.5505403520317569
# step: 61   best threshold: 0.172   best f1: 0.5514522267007126
# step: 62   best threshold: 0.174   best f1: 0.552237302868935
# step: 63   best threshold: 0.176   best f1: 0.5530299803349449
# step: 64   best threshold: 0.178   best f1: 0.5538024588125278
# step: 65   best threshold: 0.18   best f1: 0.5544661372989351
# step: 66   best threshold: 0.182   best f1: 0.5551439474268796
# step: 67   best threshold: 0.184   best f1: 0.5558371691391656
# step: 68   best threshold: 0.186   best f1: 0.5564588995612906
# step: 69   best threshold: 0.188   best f1: 0.5570314300838481
# step: 70   best threshold: 0.19   best f1: 0.5576813800890693
# step: 71   best threshold: 0.192   best f1: 0.5582387042462696
# step: 72   best threshold: 0.194   best f1: 0.558781077539268
# step: 73   best threshold: 0.196   best f1: 0.5593227250400823
# step: 74   best threshold: 0.198   best f1: 0.5598373959527674
# step: 75   best threshold: 0.2   best f1: 0.560328528584099
# step: 76   best threshold: 0.202   best f1: 0.5609096207067091
# step: 77   best threshold: 0.20400000000000001   best f1: 0.5613797028686014
# step: 78   best threshold: 0.20600000000000002   best f1: 0.5618516604872731
# step: 79   best threshold: 0.20800000000000002   best f1: 0.562348275459081
# step: 80   best threshold: 0.21000000000000002   best f1: 0.5627891048089296
# step: 81   best threshold: 0.21200000000000002   best f1: 0.5631329845981132
# step: 82   best threshold: 0.21400000000000002   best f1: 0.5635269315257159
# step: 83   best threshold: 0.21600000000000003   best f1: 0.5638742869061092
# step: 84   best threshold: 0.21800000000000003   best f1: 0.5643333197594712
# step: 85   best threshold: 0.22000000000000003   best f1: 0.5646558436502375
# step: 86   best threshold: 0.22200000000000003   best f1: 0.5650224302882665
# step: 87   best threshold: 0.22400000000000003   best f1: 0.5653156599842258
# step: 88   best threshold: 0.22599999999999998   best f1: 0.5656366701857776
# step: 89   best threshold: 0.22799999999999998   best f1: 0.5659219622545996
# step: 90   best threshold: 0.22999999999999998   best f1: 0.5661625446185733
# step: 91   best threshold: 0.23199999999999998   best f1: 0.566539942899566
# step: 92   best threshold: 0.23399999999999999   best f1: 0.5667741038399287
# step: 93   best threshold: 0.236   best f1: 0.5669602732338667
# step: 94   best threshold: 0.238   best f1: 0.5672305379713336
# step: 95   best threshold: 0.24   best f1: 0.5675133500402829
# step: 96   best threshold: 0.242   best f1: 0.5676181767380427
# step: 97   best threshold: 0.244   best f1: 0.5678118684923792
# step: 98   best threshold: 0.246   best f1: 0.5678962281636862
# step: 99   best threshold: 0.248   best f1: 0.5680277354521508
# step: 100   best threshold: 0.25   best f1: 0.5681686838498754
# step: 101   best threshold: 0.252   best f1: 0.5683920679745821
# step: 102   best threshold: 0.254   best f1: 0.5686130992235618
# step: 103   best threshold: 0.256   best f1: 0.5686885488822706
# step: 104   best threshold: 0.258   best f1: 0.5687431849677016
# step: 105   best threshold: 0.26   best f1: 0.5687985036100722
# step: 106   best threshold: 0.262   best f1: 0.5689251387072705
# step: 107   best threshold: 0.264   best f1: 0.5690421511135215
# step: 108   best threshold: 0.266   best f1: 0.5690867257540444
# step: 109   best threshold: 0.268   best f1: 0.5691656413304578
# step: 110   best threshold: 0.27   best f1: 0.5691784863962882
# step: 111   best threshold: 0.272   best f1: 0.5692714491476234
# step: 112   best threshold: 0.274   best f1: 0.5693258071857954
# step: 113   best threshold: 0.276   best f1: 0.5693541123591613
# step: 114   best threshold: 0.278   best f1: 0.5694243279334763
# step: 115   best threshold: 0.28   best f1: 0.5694586674606109
# step: 116   best threshold: 0.28200000000000003   best f1: 0.5695716369996531
# step: 117   best threshold: 0.28400000000000003   best f1: 0.5695741336528989
# search finish.
#
# best auc: 0.9105669850143522
# best f1: 0.5695741336528989
# validate mean: 0.12442684120118976
# runtime: 15527.547528028488

# %%
print('=============================================== sub save ===============================================')
sub.to_csv('sub_prob_{}_{}_{}.csv'.format(best_auc, best_f1, sub['target'].mean()), index=False)
sub['target'] = sub['target'].apply(lambda x: 1 if x >= best_t else 0)
sub.to_csv('sub_{}_{}_{}.csv'.format(best_auc, best_f1, sub['target'].mean()), index=False)
print('runtime:', time.time() - t)
print('finish.')
print('========================================================================================================')
# Out:
# =============================================== sub save ===============================================
# runtime: 15559.546869516373
# finish.
# ========================================================================================================
